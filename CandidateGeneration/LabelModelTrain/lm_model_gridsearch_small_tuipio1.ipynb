# %%
import enum
import glob
import os
from hashlib import new
from pathlib import Path
import time

import functools

import numpy as np
import pandas as pd
import scipy
from flyingsquid.label_model import LabelModel as LMsquid
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from snorkel.labeling.model import LabelModel as LMsnorkel
from snorkel.labeling.model import MajorityLabelVoter

# %%
from sklearn.exceptions import UndefinedMetricWarning

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
def list2Nested(l, nested_length):
    return [l[i:i+nested_length] for i in range(0, len(l), nested_length)]

# %%
# Fetch UMLS ranks

sum_lf_p = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/lf_p_summary_train.csv'
sum_lf_i = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/lf_i_summary_train.csv'
sum_lf_o = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/lf_o_summary_train.csv'


def fetchRank(sum_lf_d):
    
    ranked_umls_coverage = dict()    
    umls_coverage_ = dict()
    
    data=pd.read_csv(sum_lf_d, sep='\t')
    
    for index, row in data.iterrows():
        if row[0].startswith('UMLS_fuzzy_'):
            umls_coverage_[row[0]] = row[3]
    
    umls_coverage_sorted = sorted(umls_coverage_.items(), key=lambda x: x[1], reverse=True)
    
    for i in umls_coverage_sorted:
        k = str(i[0]).split('_')[-1]
        ranked_umls_coverage[k] = i[1]

    return ranked_umls_coverage

ranksorted_p_umls = fetchRank(sum_lf_p)
ranksorted_i_umls = fetchRank(sum_lf_i)
ranksorted_o_umls = fetchRank(sum_lf_o)

# %%
# Partition LF's

def partitionLFs(umls_d):
    
    keys = list(umls_d.keys())

    partitioned_lfs = [ ]
    
    for i in range( 0, len(keys) ):

        if i == 0 or i == len(keys):
            if i == 0:
                partitioned_lfs.append( [keys] )
            if i ==len(keys):
                temp3 = list2Nested(keys, 1)
                partitioned_lfs.append( temp3 )
        else:
            temp1, temp2 = keys[:i] , keys[i:]
            temp3 = list2Nested( keys[:i], 1)
            temp3.append( keys[i:] )
            partitioned_lfs.append( temp3 )
    
    return partitioned_lfs


partitioned_p_umls = partitionLFs(ranksorted_p_umls)
partitioned_i_umls = partitionLFs(ranksorted_i_umls)
partitioned_o_umls = partitionLFs(ranksorted_o_umls)

# %%
import LMutils

# validation_labels   
# validation_labels_tui_pio2   
file = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/validation_labels_tui_pio2.tsv'
df_data = pd.read_csv(file, sep='\t', header=0)

# %%
Y_tokens = df_data['tokens']
df_data_train, df_data_val = train_test_split(df_data, test_size=0.20, shuffle=False)

# %%
# Read Candidate labels from multiple LFs
indir = '/mnt/nas2/results/Results/systematicReview/distant_pico/candidate_generation'
pathlist = Path(indir).glob('**/*.tsv')

tokens = []

lfs = dict()

for file in pathlist:

    k = str( file ).split('candidate_generation/')[-1].replace('.tsv', '').replace('/', '_')
    mypath = Path(file)
    if mypath.stat().st_size != 0:
        data = pd.read_csv(file, sep='\t', header=0)
    if len(tokens) == 0:
        tokens.extend( list(data.tokens) )
    
    sab = data.columns[-1]
    if len(list( data[sab] )) == 1354953:
        lfs[str(k)] = list( data[sab] )[:len(Y_tokens)]


print( 'Total number of tokens in validation set: ', len(tokens) )
print( 'Total number of LFs in the dictionary', len(lfs) )
# Out:
# Total number of tokens in validation set:  1354953
# Total number of LFs in the dictionary 617

# %%
dict_p_lfs = pd.DataFrame({ key:pd.Series(value) for key, value in lfs.items() if '_P_lf_' in key or '_p_lf_' in key })
dict_i_lfs = pd.DataFrame({ key:pd.Series(value) for key, value in lfs.items() if '_I_lf_' in key or '_i_lf_' in key })
dict_o_lfs = pd.DataFrame({ key:pd.Series(value) for key, value in lfs.items() if '_O_lf_' in key or '_o_lf_' in key })

# %%
def lf_levels(umls_d:dict, pattern:str, picos:str):

    umls_level = dict()

    for key, value in umls_d.items():   # iter on both keys and values
        search_pattern = pattern + picos
        if key.startswith(search_pattern):
            k = str(key).split('_')[-1]
            umls_level[ k ] = value

    return umls_level

# Level 1: UMLS
umls_p = lf_levels(lfs, 'UMLS_fuzzy_', 'p')
umls_i = lf_levels(lfs, 'UMLS_fuzzy_', 'i')
umls_o = lf_levels(lfs, 'UMLS_fuzzy_', 'o')

# Level 2: non UMLS
nonumls_p = lf_levels(lfs, 'nonUMLS_fuzzy_', 'P')
nonumls_i = lf_levels(lfs, 'nonUMLS_fuzzy_', 'I')
nonumls_o = lf_levels(lfs, 'nonUMLS_fuzzy_', 'O')

# Level 3: DS
ds_p = lf_levels(lfs, 'DS_fuzzy_', 'P')
ds_i = lf_levels(lfs, 'DS_fuzzy_', 'I')
ds_o = lf_levels(lfs, 'DS_fuzzy_', 'O')

# Level 4: dictionary, rules, heuristics
heur_p = lf_levels(lfs, 'heuristics_direct_', 'P')
heur_i = lf_levels(lfs, 'heuristics_direct_', 'I')
heur_o = lf_levels(lfs, 'heuristics_direct_', 'O')

dict_p = lf_levels(lfs, 'dictionary_direct_', 'P')
dict_i = lf_levels(lfs, 'dictionary_direct_', 'I')
dict_o = lf_levels(lfs, 'dictionary_direct_', 'O')

# %%
def compare(s, t):
    return sorted(s) == sorted(t)

def getLFs(partition:list, umls_d:dict, seed_len:int):

    all_lfs_combined = []
    
    for lf in partition: # for each lf in a partition
        
        combine_here = [0] * seed_len

        for sab in lf:
            new_a = umls_d[sab]
            old_a = combine_here
            temp_a = []
            for o_a, n_a in zip(old_a, new_a):
                if compare([o_a, n_a] ,[-1, 1]) == True:
                    replace_a = max( o_a, n_a )
                    temp_a.append( replace_a )
                elif compare([o_a, n_a] ,[0, 1]) == True:
                    replace_a = max( o_a, n_a )
                    temp_a.append( replace_a )
                elif compare([o_a, n_a] ,[-1, 0]) == True:
                    replace_a = min( o_a, n_a )
                    temp_a.append( replace_a )
                else:
                    temp_a.append( o_a )

            combine_here = temp_a

        all_lfs_combined.append( combine_here )

    return all_lfs_combined

# %%
def grid_search(model_class,
                model_class_init,
                param_grid,
                train=None,
                dev=None,
                other_train=None,
                n_model_search=5,
                val_metric='f1_macro',
                seed=1234,
                checkpoint_gt_mv=False,
                tag_fmt_ckpnt='IO'):
    
    
    """Simple grid search helper function

    Parameters
    ----------
    model_class
    model_class_init
    param_grid
    train
    dev
    n_model_search
    val_metric
    seed

    Returns
    -------
    

    """
    
    
    L_train, Y_train = train
    L_dev, Y_dev = dev
    
    # sample configs
    params = sample_param_grid(param_grid, seed)[:n_model_search]
    
    defaults = {'seed': seed}
    best_score, best_config = 0.0, None
    print(f"Grid search over {len(params)} configs")
    
    for i, config in enumerate(params):
        print(f'[{i}] Label Model')
        config = dict(zip(param_grid.keys(), config))
        # update default params if not specified
        config.update({param: value for param, value in defaults.items() if param not in config})

        model = model_class(**model_class_init)
        model.fit(L_train, Y_dev, **config)
        
        y_pred = model.predict(L_dev)
        
        # set gold tags for evaluation
        if tag_fmt_ckpnt == 'IO':
            y_gold = np.array([0 if y == 0 else 1 for y in Y_dev])
        else:
            y_gold = Y_dev
            
            
        if -1 in y_pred:
            print("Label model predicted -1 (TODO: this happens inconsistently)")
            continue
            
        # use internal label model scorer to score the prediction
        metrics = model.score(L=L_dev,
                              Y=y_gold,
                              metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
                              tie_break_policy='random')
        
    
        # compare learned model against MV on same labeled dev set
        # skip if LM less than MV
        if checkpoint_gt_mv:
            mv_metrics = model.score(L=L_dev,
                                  Y=y_gold,
                                  metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
                                  tie_break_policy='random')

            if metrics[val_metric] < mv_metrics[val_metric]:
                continue
                
        if not best_score or metrics[val_metric] > best_score[val_metric]:
            print(config)
            best_score = metrics
            best_config = config
            
            # print training set score if we have labeled data
            if np.any(Y_train):
                y_pred = model.predict(L_train)

                if tag_fmt_ckpnt == 'IO':
                    y_gold = np.array([0 if y == 0 else 1 for y in Y_train])
                else:
                    y_gold = Y_train

                metrics = model.score(L=L_train,
                                      Y=y_gold,
                                      metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
                                      tie_break_policy='random')

                print('[TRAIN] {}'.format(' | '.join([f'{m}: {v * 100:2.2f}' for m, v in metrics.items()])))

            print('[DEV]   {}'.format(' | '.join([f'{m}: {v * 100:2.2f}' for m, v in best_score.items()])))
            print('-' * 88)
            
            
    # retrain best model
    print('BEST')
    print(best_config)
    model = model_class(**model_class_init)
    
    
    model.fit(L_train, Y_dev, **best_config)
    return model, best_config, best_score

# %%
def train(partitioned_d_umls, umls_d, non_umls_d, ds_d, heur_d, dict_d, df_data_train, df_data_val, picos, paramgrid):
   

    best_f1_macro = 0.0
    best_overall_model = ''
    best_overall_config = ''
    
    
    model_class_init = {
        'cardinality': 2, 
        'verbose': True
    }

    num_hyperparams = functools.reduce(lambda x,y:x*y, [len(x) for x in param_grid.values()])
    print("Hyperparamater Search Space:", num_hyperparams)
    n_model_search = 25
    


    '''#########################################################################
    # Choosing the number of LF's from UMLS all
    #########################################################################'''
    
    for i, partition in enumerate(partitioned_d_umls):
        
        if len( partition ) >= 0:

            combined_lf = getLFs(partition, umls_d, len(Y_tokens))
            assert len(partition) == len(combined_lf)

            print( 'Total number of UMLS partitions: ', len(partition) )
            combined_lf.extend( list(non_umls_d.values()) ) # Combine with level 2
            combined_lf.extend( list(ds_d.values()) ) # Combine with level 3
            combined_lf.extend( list(heur_d.values()) ) # Combine with level 4
            combined_lf.extend( list(dict_d.values()) ) # combine with level 4

            L = np.array(combined_lf)
            L = np.transpose(L)
            L_train, L_val = train_test_split(L, test_size=0.20, shuffle=False)

            Y_train = df_data_train[picos]
            Y_val = df_data_val[picos]


            best_model, best_config, best_score = grid_search(LMsnorkel, 
                                               model_class_init, 
                                               paramgrid,
                                               train = (L_train, Y_train),
                                               dev = (L_val, Y_val),
                                               n_model_search=n_model_search, 
                                               val_metric='f1_macro', 
                                               seed=1234,
                                               tag_fmt_ckpnt='IO')

            if best_score['f1_macro'] > best_f1_macro:
                best_f1_macro = best_score['f1_macro']
                best_overall_model = best_model
                best_overall_config = best_config


            print('Best overall macro F1 score: ', best_f1_macro)
            print('Best overall configuration: ', best_overall_config)

# %%
param_grid = {
    'lr': [0.001, 0.0001],
    'l2': [0.001, 0.0001],
    'n_epochs': [50, 100, 200, 600, 700, 1000, 2000],
    'prec_init': [0.6, 0.7, 0.8, 0.9],
    'optimizer': ["adamax", "adam", "sgd"],
    'lr_scheduler': ['constant'],
}

# %%
train(partitioned_p_umls, umls_p, nonumls_p, ds_p, heur_p, dict_p, df_data_train, df_data_val, 'p', paramgrid = param_grid)
# Out:
# Hyperparamater Search Space: 336
# Total number of UMLS partitions:  1
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.89 | precision: 0.00 | recall: 0.00 | f1: 0.00 | f1_macro: 46.78
# [DEV]   accuracy: 87.70 | precision: 0.00 | recall: 0.00 | f1: 0.00 | f1_macro: 46.72
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.05 | precision: 32.19 | recall: 6.29 | f1: 10.52 | f1_macro: 51.77
# [DEV]   accuracy: 86.93 | precision: 33.68 | recall: 6.46 | f1: 10.84 | f1_macro: 51.89
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.21 | precision: 24.33 | recall: 10.51 | f1: 14.67 | f1_macro: 53.29
# [DEV]   accuracy: 85.14 | precision: 25.40 | recall: 10.73 | f1: 15.09 | f1_macro: 53.47
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  2
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.95 | precision: 74.77 | recall: 0.76 | f1: 1.50 | f1_macro: 47.54
# [DEV]   accuracy: 87.78 | precision: 74.09 | recall: 0.98 | f1: 1.93 | f1_macro: 47.71
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.04 | precision: 32.14 | recall: 6.32 | f1: 10.57 | f1_macro: 51.79
# [DEV]   accuracy: 86.91 | precision: 33.44 | recall: 6.50 | f1: 10.88 | f1_macro: 51.91
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.18 | precision: 24.24 | recall: 10.54 | f1: 14.69 | f1_macro: 53.29
# [DEV]   accuracy: 85.10 | precision: 25.22 | recall: 10.76 | f1: 15.08 | f1_macro: 53.46
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.33 | precision: 24.86 | recall: 10.45 | f1: 14.71 | f1_macro: 53.35
# [DEV]   accuracy: 85.25 | precision: 25.81 | recall: 10.65 | f1: 15.07 | f1_macro: 53.50
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  6
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.96 | precision: 58.45 | recall: 2.01 | f1: 3.89 | f1_macro: 48.73
# [DEV]   accuracy: 87.80 | precision: 60.50 | recall: 2.27 | f1: 4.37 | f1_macro: 48.93
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.36 | precision: 36.68 | recall: 6.06 | f1: 10.41 | f1_macro: 51.80
# [DEV]   accuracy: 87.22 | precision: 38.14 | recall: 6.28 | f1: 10.78 | f1_macro: 51.95
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.28 | precision: 24.89 | recall: 10.66 | f1: 14.93 | f1_macro: 53.44
# [DEV]   accuracy: 85.21 | precision: 25.88 | recall: 10.87 | f1: 15.31 | f1_macro: 53.61
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.36 | precision: 29.77 | recall: 9.32 | f1: 14.19 | f1_macro: 53.39
# [DEV]   accuracy: 86.28 | precision: 31.27 | recall: 9.63 | f1: 14.72 | f1_macro: 53.63
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model

# %%
train(partitioned_i_umls, umls_i, nonumls_i, ds_i, heur_i, dict_i, df_data_train, df_data_val, 'i', paramgrid = param_grid)
# Out:
# Hyperparamater Search Space: 336
# Total number of UMLS partitions:  1
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.70 | precision: 48.79 | recall: 3.74 | f1: 6.94 | f1_macro: 51.02
# [DEV]   accuracy: 90.62 | precision: 47.69 | recall: 3.88 | f1: 7.17 | f1_macro: 51.12
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.31 | precision: 27.03 | recall: 27.94 | f1: 27.48 | f1_macro: 59.96
# [DEV]   accuracy: 86.20 | precision: 27.05 | recall: 28.08 | f1: 27.56 | f1_macro: 59.97
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.23 | precision: 27.02 | recall: 28.37 | f1: 27.68 | f1_macro: 60.03
# [DEV]   accuracy: 86.11 | precision: 26.96 | recall: 28.47 | f1: 27.70 | f1_macro: 60.01
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  2
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.39 | precision: 35.15 | recall: 4.09 | f1: 7.34 | f1_macro: 51.13
# [DEV]   accuracy: 90.36 | precision: 36.68 | recall: 4.42 | f1: 7.89 | f1_macro: 51.40
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.45 | precision: 27.04 | recall: 27.03 | f1: 27.03 | f1_macro: 59.78
# [DEV]   accuracy: 86.36 | precision: 27.07 | recall: 27.15 | f1: 27.11 | f1_macro: 59.79
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  3
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.41 | precision: 35.52 | recall: 4.00 | f1: 7.19 | f1_macro: 51.07
# [DEV]   accuracy: 90.38 | precision: 37.06 | recall: 4.30 | f1: 7.70 | f1_macro: 51.31
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.13 | precision: 36.88 | recall: 8.93 | f1: 14.38 | f1_macro: 54.57
# [DEV]   accuracy: 90.10 | precision: 37.84 | recall: 9.29 | f1: 14.91 | f1_macro: 54.83
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.45 | precision: 27.04 | recall: 27.03 | f1: 27.03 | f1_macro: 59.78
# [DEV]   accuracy: 86.36 | precision: 27.07 | recall: 27.15 | f1: 27.11 | f1_macro: 59.79
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  4
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.44 | precision: 34.44 | recall: 3.28 | f1: 5.99 | f1_macro: 50.48
# [DEV]   accuracy: 90.42 | precision: 36.82 | recall: 3.53 | f1: 6.44 | f1_macro: 50.69
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.11 | precision: 36.64 | recall: 9.00 | f1: 14.45 | f1_macro: 54.60
# [DEV]   accuracy: 90.08 | precision: 37.60 | recall: 9.33 | f1: 14.95 | f1_macro: 54.84
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 88.50 | precision: 27.03 | recall: 14.06 | f1: 18.50 | f1_macro: 56.15
# [DEV]   accuracy: 88.42 | precision: 27.07 | recall: 14.12 | f1: 18.56 | f1_macro: 56.16
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.13 | precision: 22.46 | recall: 20.16 | f1: 21.25 | f1_macro: 56.82
# [DEV]   accuracy: 86.11 | precision: 22.79 | recall: 20.37 | f1: 21.51 | f1_macro: 56.95
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  39
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.63 | precision: 36.78 | recall: 1.29 | f1: 2.49 | f1_macro: 48.79
# [DEV]   accuracy: 90.59 | precision: 38.39 | recall: 1.24 | f1: 2.40 | f1_macro: 48.73
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 88.40 | precision: 26.63 | recall: 14.22 | f1: 18.54 | f1_macro: 56.15
# [DEV]   accuracy: 88.32 | precision: 26.66 | recall: 14.30 | f1: 18.61 | f1_macro: 56.16
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.78 | precision: 21.89 | recall: 20.72 | f1: 21.29 | f1_macro: 56.73
# [DEV]   accuracy: 85.75 | precision: 22.12 | recall: 20.84 | f1: 21.46 | f1_macro: 56.81
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  40
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.61 | precision: 36.29 | recall: 1.55 | f1: 2.97 | f1_macro: 49.02
# [DEV]   accuracy: 90.56 | precision: 36.41 | recall: 1.43 | f1: 2.76 | f1_macro: 48.90
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 88.36 | precision: 26.61 | recall: 14.43 | f1: 18.71 | f1_macro: 56.22
# [DEV]   accuracy: 88.28 | precision: 26.57 | recall: 14.44 | f1: 18.71 | f1_macro: 56.20
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.31 | precision: 21.67 | recall: 22.27 | f1: 21.97 | f1_macro: 56.93
# [DEV]   accuracy: 85.26 | precision: 21.82 | recall: 22.34 | f1: 22.07 | f1_macro: 56.97
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  41
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 90.51 | precision: 34.82 | recall: 2.52 | f1: 4.69 | f1_macro: 49.85
# [DEV]   accuracy: 90.45 | precision: 34.70 | recall: 2.53 | f1: 4.72 | f1_macro: 49.85
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.87 | precision: 25.04 | recall: 15.39 | f1: 19.06 | f1_macro: 56.25
# [DEV]   accuracy: 87.79 | precision: 25.20 | recall: 15.60 | f1: 19.27 | f1_macro: 56.33
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.25 | precision: 21.62 | recall: 22.42 | f1: 22.01 | f1_macro: 56.93
# [DEV]   accuracy: 85.21 | precision: 21.78 | recall: 22.50 | f1: 22.13 | f1_macro: 56.98
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.6000773130770576
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}

# %%
train(partitioned_o_umls, umls_o, nonumls_o, ds_o, heur_o, dict_o, df_data_train, df_data_val, 'o', paramgrid = param_grid)
# Out:
# Hyperparamater Search Space: 336
# Total number of UMLS partitions:  1
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.29 | precision: 26.29 | recall: 5.98 | f1: 9.75 | f1_macro: 51.46
# [DEV]   accuracy: 87.11 | precision: 25.20 | recall: 5.68 | f1: 9.27 | f1_macro: 51.16
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.50 | precision: 26.07 | recall: 14.40 | f1: 18.55 | f1_macro: 55.30
# [DEV]   accuracy: 85.32 | precision: 25.89 | recall: 14.30 | f1: 18.42 | f1_macro: 55.18
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 74.70 | precision: 20.16 | recall: 40.72 | f1: 26.97 | f1_macro: 55.83
# [DEV]   accuracy: 74.65 | precision: 20.27 | recall: 40.49 | f1: 27.02 | f1_macro: 55.84
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.558385595123765
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  2
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.50 | precision: 26.55 | recall: 5.08 | f1: 8.53 | f1_macro: 50.91
# [DEV]   accuracy: 87.35 | precision: 25.78 | recall: 4.86 | f1: 8.18 | f1_macro: 50.70
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.27 | precision: 32.51 | recall: 18.32 | f1: 23.43 | f1_macro: 57.95
# [DEV]   accuracy: 86.10 | precision: 32.07 | recall: 17.80 | f1: 22.89 | f1_macro: 57.63
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.54 | precision: 25.41 | recall: 26.97 | f1: 26.17 | f1_macro: 58.13
# [DEV]   accuracy: 82.43 | precision: 25.36 | recall: 26.56 | f1: 25.94 | f1_macro: 57.99
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5855618601718491
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  79
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 88.04 | precision: 37.26 | recall: 6.30 | f1: 10.78 | f1_macro: 52.18
# [DEV]   accuracy: 87.86 | precision: 36.01 | recall: 6.05 | f1: 10.36 | f1_macro: 51.92
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.11 | precision: 32.00 | recall: 18.79 | f1: 23.68 | f1_macro: 58.02
# [DEV]   accuracy: 85.94 | precision: 31.58 | recall: 18.25 | f1: 23.13 | f1_macro: 57.70
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.52 | precision: 25.40 | recall: 27.07 | f1: 26.21 | f1_macro: 58.15
# [DEV]   accuracy: 82.40 | precision: 25.34 | recall: 26.64 | f1: 25.97 | f1_macro: 57.99
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5855618601718491
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  80
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 88.02 | precision: 37.18 | recall: 6.45 | f1: 10.99 | f1_macro: 52.28
# [DEV]   accuracy: 87.85 | precision: 36.04 | recall: 6.20 | f1: 10.57 | f1_macro: 52.03
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.10 | precision: 32.01 | recall: 18.91 | f1: 23.77 | f1_macro: 58.06
# [DEV]   accuracy: 85.95 | precision: 31.75 | recall: 18.45 | f1: 23.33 | f1_macro: 57.80
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.52 | precision: 25.41 | recall: 27.09 | f1: 26.22 | f1_macro: 58.15
# [DEV]   accuracy: 82.40 | precision: 25.37 | recall: 26.69 | f1: 26.01 | f1_macro: 58.01
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5855618601718491
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  81
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 88.04 | precision: 37.31 | recall: 6.37 | f1: 10.88 | f1_macro: 52.23
# [DEV]   accuracy: 87.87 | precision: 36.27 | recall: 6.16 | f1: 10.54 | f1_macro: 52.01
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.11 | precision: 31.96 | recall: 18.68 | f1: 23.58 | f1_macro: 57.97
# [DEV]   accuracy: 85.98 | precision: 31.75 | recall: 18.25 | f1: 23.18 | f1_macro: 57.73
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.59 | precision: 25.50 | recall: 26.98 | f1: 26.22 | f1_macro: 58.17
# [DEV]   accuracy: 82.46 | precision: 25.42 | recall: 26.54 | f1: 25.97 | f1_macro: 58.01
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5855618601718491
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}

# %%
train(partitioned_p_umls, umls_p, nonumls_p, ds_p, heur_p, dict_p, df_data_train, df_data_val, 'p', paramgrid = param_grid)
# Out:
# Hyperparamater Search Space: 336
# Total number of UMLS partitions:  40
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.58 | precision: 40.81 | recall: 5.78 | f1: 10.12 | f1_macro: 51.73
# [DEV]   accuracy: 87.43 | precision: 42.05 | recall: 5.81 | f1: 10.20 | f1_macro: 51.72
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.84 | precision: 28.60 | recall: 11.29 | f1: 16.19 | f1_macro: 54.23
# [DEV]   accuracy: 85.73 | precision: 29.34 | recall: 11.37 | f1: 16.39 | f1_macro: 54.29
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.10 | precision: 24.91 | recall: 19.65 | f1: 21.97 | f1_macro: 56.25
# [DEV]   accuracy: 83.05 | precision: 25.62 | recall: 19.88 | f1: 22.39 | f1_macro: 56.44
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# ...
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.54 | precision: 41.16 | recall: 6.74 | f1: 11.59 | f1_macro: 52.44
# [DEV]   accuracy: 87.40 | precision: 42.27 | recall: 6.63 | f1: 11.46 | f1_macro: 52.34
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.69 | precision: 32.96 | recall: 17.55 | f1: 22.90 | f1_macro: 57.51
# [DEV]   accuracy: 85.55 | precision: 33.32 | recall: 17.49 | f1: 22.94 | f1_macro: 57.48
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.33 | precision: 28.98 | recall: 20.25 | f1: 23.84 | f1_macro: 57.56
# [DEV]   accuracy: 84.27 | precision: 29.73 | recall: 20.45 | f1: 24.23 | f1_macro: 57.73
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5782505525605598
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  66
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.52 | precision: 40.76 | recall: 6.82 | f1: 11.68 | f1_macro: 52.48
# [DEV]   accuracy: 87.39 | precision: 42.00 | recall: 6.71 | f1: 11.57 | f1_macro: 52.39
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.56 | precision: 32.52 | recall: 17.88 | f1: 23.08 | f1_macro: 57.56
# [DEV]   accuracy: 85.44 | precision: 33.05 | recall: 17.93 | f1: 23.25 | f1_macro: 57.60
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.24 | precision: 28.78 | recall: 20.43 | f1: 23.90 | f1_macro: 57.55
# [DEV]   accuracy: 84.17 | precision: 29.51 | recall: 20.66 | f1: 24.30 | f1_macro: 57.73
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5782505525605598
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  67
# Grid search over 25 configs
# [0] Label Model
# Label model predicted -1 (TODO: this happens inconsistently)
# [1] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 100, 'prec_init': 0.9, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.89 | precision: 49.75 | recall: 1.00 | f1: 1.95 | f1_macro: 47.75
# [DEV]   accuracy: 87.73 | precision: 54.88 | recall: 1.13 | f1: 2.22 | f1_macro: 47.83
# ----------------------------------------------------------------------------------------
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.54 | precision: 32.46 | recall: 17.97 | f1: 23.14 | f1_macro: 57.58
# [DEV]   accuracy: 85.41 | precision: 32.98 | recall: 18.03 | f1: 23.32 | f1_macro: 57.63
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.21 | precision: 28.84 | recall: 20.69 | f1: 24.09 | f1_macro: 57.64
# [DEV]   accuracy: 84.15 | precision: 29.60 | recall: 20.93 | f1: 24.52 | f1_macro: 57.83
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5783322738359847
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  68
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.50 | precision: 40.52 | recall: 6.91 | f1: 11.81 | f1_macro: 52.54
# [DEV]   accuracy: 87.36 | precision: 41.64 | recall: 6.84 | f1: 11.75 | f1_macro: 52.47
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.55 | precision: 32.48 | recall: 17.94 | f1: 23.11 | f1_macro: 57.57
# [DEV]   accuracy: 85.42 | precision: 33.02 | recall: 18.01 | f1: 23.30 | f1_macro: 57.63
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.26 | precision: 28.94 | recall: 20.59 | f1: 24.06 | f1_macro: 57.64
# [DEV]   accuracy: 84.19 | precision: 29.68 | recall: 20.82 | f1: 24.47 | f1_macro: 57.82
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5783322738359847
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  69
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.45 | precision: 39.77 | recall: 7.10 | f1: 12.05 | f1_macro: 52.65
# [DEV]   accuracy: 87.32 | precision: 41.05 | recall: 7.12 | f1: 12.13 | f1_macro: 52.65
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.51 | precision: 32.42 | recall: 18.14 | f1: 23.26 | f1_macro: 57.63
# [DEV]   accuracy: 85.37 | precision: 32.86 | recall: 18.15 | f1: 23.39 | f1_macro: 57.65
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.83 | precision: 27.90 | recall: 21.19 | f1: 24.09 | f1_macro: 57.52
# [DEV]   accuracy: 83.78 | precision: 28.68 | recall: 21.43 | f1: 24.53 | f1_macro: 57.72
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5783322738359847
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  70
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.45 | precision: 39.75 | recall: 7.11 | f1: 12.06 | f1_macro: 52.65
# [DEV]   accuracy: 87.32 | precision: 41.06 | recall: 7.13 | f1: 12.14 | f1_macro: 52.66
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.51 | precision: 32.45 | recall: 18.18 | f1: 23.31 | f1_macro: 57.65
# [DEV]   accuracy: 85.38 | precision: 32.94 | recall: 18.22 | f1: 23.46 | f1_macro: 57.69
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.83 | precision: 27.94 | recall: 21.23 | f1: 24.13 | f1_macro: 57.54
# [DEV]   accuracy: 83.79 | precision: 28.76 | recall: 21.50 | f1: 24.61 | f1_macro: 57.76
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5783322738359847
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  71
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.44 | precision: 39.73 | recall: 7.15 | f1: 12.12 | f1_macro: 52.68
# [DEV]   accuracy: 87.32 | precision: 41.08 | recall: 7.18 | f1: 12.23 | f1_macro: 52.70
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.48 | precision: 32.37 | recall: 18.29 | f1: 23.37 | f1_macro: 57.67
# [DEV]   accuracy: 85.35 | precision: 32.87 | recall: 18.34 | f1: 23.54 | f1_macro: 57.72
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.91 | precision: 28.33 | recall: 21.49 | f1: 24.44 | f1_macro: 57.72
# [DEV]   accuracy: 83.87 | precision: 29.12 | recall: 21.72 | f1: 24.88 | f1_macro: 57.92
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5792263788920823
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  72
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.42 | precision: 39.41 | recall: 7.28 | f1: 12.29 | f1_macro: 52.76
# [DEV]   accuracy: 87.30 | precision: 40.93 | recall: 7.36 | f1: 12.48 | f1_macro: 52.82
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.41 | precision: 32.23 | recall: 18.58 | f1: 23.57 | f1_macro: 57.75
# [DEV]   accuracy: 85.29 | precision: 32.79 | recall: 18.66 | f1: 23.78 | f1_macro: 57.82
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.70 | precision: 28.01 | recall: 22.04 | f1: 24.67 | f1_macro: 57.76
# [DEV]   accuracy: 83.70 | precision: 28.90 | recall: 22.31 | f1: 25.18 | f1_macro: 58.02
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5801774638304952
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
