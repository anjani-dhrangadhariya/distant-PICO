# %%
import enum
import glob
import os
from hashlib import new
from pathlib import Path
import time

import functools

import numpy as np
import pandas as pd
import scipy
from flyingsquid.label_model import LabelModel as LMsquid
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from snorkel.labeling.model import LabelModel as LMsnorkel
from snorkel.labeling.model import MajorityLabelVoter

# %%
from sklearn.exceptions import UndefinedMetricWarning

def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
def list2Nested(l, nested_length):
    return [l[i:i+nested_length] for i in range(0, len(l), nested_length)]

# %%
# Fetch UMLS ranks

sum_lf_p = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/lf_p_summary_train.csv'
sum_lf_i = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/lf_i_summary_train.csv'
sum_lf_o = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/lf_o_summary_train.csv'


def fetchRank(sum_lf_d):
    
    ranked_umls_coverage = dict()    
    umls_coverage_ = dict()
    
    data=pd.read_csv(sum_lf_d, sep='\t')
    
    for index, row in data.iterrows():
        if row[0].startswith('UMLS_fuzzy_'):
            umls_coverage_[row[0]] = row[3]
    
    umls_coverage_sorted = sorted(umls_coverage_.items(), key=lambda x: x[1], reverse=True)
    
    for i in umls_coverage_sorted:
        k = str(i[0]).split('_')[-1]
        ranked_umls_coverage[k] = i[1]

    return ranked_umls_coverage

ranksorted_p_umls = fetchRank(sum_lf_p)
ranksorted_i_umls = fetchRank(sum_lf_i)
ranksorted_o_umls = fetchRank(sum_lf_o)

# %%
# Partition LF's

def partitionLFs(umls_d):
    
    keys = list(umls_d.keys())

    partitioned_lfs = [ ]
    
    for i in range( 0, len(keys) ):

        if i == 0 or i == len(keys):
            if i == 0:
                partitioned_lfs.append( [keys] )
            if i ==len(keys):
                temp3 = list2Nested(keys, 1)
                partitioned_lfs.append( temp3 )
        else:
            temp1, temp2 = keys[:i] , keys[i:]
            temp3 = list2Nested( keys[:i], 1)
            temp3.append( keys[i:] )
            partitioned_lfs.append( temp3 )
    
    return partitioned_lfs


partitioned_p_umls = partitionLFs(ranksorted_p_umls)
partitioned_i_umls = partitionLFs(ranksorted_i_umls)
partitioned_o_umls = partitionLFs(ranksorted_o_umls)

# %%
import LMutils

# validation_labels   
# validation_labels_tui_pio2   
file = '/mnt/nas2/results/Results/systematicReview/distant_pico/EBM_PICO_GT/validation_labels_tui_pio2.tsv'
df_data = pd.read_csv(file, sep='\t', header=0)

# %%
Y_tokens = df_data['tokens']

# %%
Y_tokens = df_data['tokens']
#Y_p = df_data['p']
#Y_i = df_data['i']
#Y_o = df_data['o']
df_data_train, df_data_val = train_test_split(df_data, test_size=0.20, shuffle=False)

# %%
splits = ['train', 'dev']
X_sents = [
    df_data_train.tokens,
    df_data_val.tokens,
]

# %%
X_seq_lens = [
    np.array([len(str(s)) for s in X_sents[i]])
    for i,name in enumerate(splits)
]

# %%
X_seq_lens = [
    np.array( [ len(X_sents[i]) ] )
    for i,name in enumerate(splits)
]

# %%
# Read Candidate labels from multiple LFs
indir = '/mnt/nas2/results/Results/systematicReview/distant_pico/candidate_generation'
pathlist = Path(indir).glob('**/*.tsv')

tokens = []

lfs = dict()

for file in pathlist:

    k = str( file ).split('candidate_generation/')[-1].replace('.tsv', '').replace('/', '_')
    mypath = Path(file)
    if mypath.stat().st_size != 0:
        data = pd.read_csv(file, sep='\t', header=0)
    if len(tokens) == 0:
        tokens.extend( list(data.tokens) )
    
    sab = data.columns[-1]
    if len(list( data[sab] )) == 1354953:
        lfs[str(k)] = list( data[sab] )[:len(Y_tokens)]


print( 'Total number of tokens in validation set: ', len(tokens) )
print( 'Total number of LFs in the dictionary', len(lfs) )
# Out:
# Total number of tokens in validation set:  1354953
# Total number of LFs in the dictionary 617

# %%
dict_p_lfs = pd.DataFrame({ key:pd.Series(value) for key, value in lfs.items() if '_P_lf_' in key or '_p_lf_' in key })
dict_i_lfs = pd.DataFrame({ key:pd.Series(value) for key, value in lfs.items() if '_I_lf_' in key or '_i_lf_' in key })
dict_o_lfs = pd.DataFrame({ key:pd.Series(value) for key, value in lfs.items() if '_O_lf_' in key or '_o_lf_' in key })

# %%
def lf_levels(umls_d:dict, pattern:str, picos:str):

    umls_level = dict()

    for key, value in umls_d.items():   # iter on both keys and values
        search_pattern = pattern + picos
        if key.startswith(search_pattern):
            k = str(key).split('_')[-1]
            umls_level[ k ] = value

    return umls_level

# Level 1: UMLS
umls_p = lf_levels(lfs, 'UMLS_fuzzy_', 'p')
umls_i = lf_levels(lfs, 'UMLS_fuzzy_', 'i')
umls_o = lf_levels(lfs, 'UMLS_fuzzy_', 'o')

# Level 2: non UMLS
nonumls_p = lf_levels(lfs, 'nonUMLS_fuzzy_', 'P')
nonumls_i = lf_levels(lfs, 'nonUMLS_fuzzy_', 'I')
nonumls_o = lf_levels(lfs, 'nonUMLS_fuzzy_', 'O')

# Level 3: DS
ds_p = lf_levels(lfs, 'DS_fuzzy_', 'P')
ds_i = lf_levels(lfs, 'DS_fuzzy_', 'I')
ds_o = lf_levels(lfs, 'DS_fuzzy_', 'O')

# Level 4: dictionary, rules, heuristics
heur_p = lf_levels(lfs, 'heuristics_direct_', 'P')
heur_i = lf_levels(lfs, 'heuristics_direct_', 'I')
heur_o = lf_levels(lfs, 'heuristics_direct_', 'O')

dict_p = lf_levels(lfs, 'dictionary_direct_', 'P')
dict_i = lf_levels(lfs, 'dictionary_direct_', 'I')
dict_o = lf_levels(lfs, 'dictionary_direct_', 'O')

# %%
def compare(s, t):
    return sorted(s) == sorted(t)

def getLFs(partition:list, umls_d:dict, seed_len:int):

    all_lfs_combined = []
    
    for lf in partition: # for each lf in a partition
        
        combine_here = [0] * seed_len

        for sab in lf:
            new_a = umls_d[sab]
            old_a = combine_here
            temp_a = []
            for o_a, n_a in zip(old_a, new_a):
                if compare([o_a, n_a] ,[-1, 1]) == True:
                    replace_a = max( o_a, n_a )
                    temp_a.append( replace_a )
                elif compare([o_a, n_a] ,[0, 1]) == True:
                    replace_a = max( o_a, n_a )
                    temp_a.append( replace_a )
                elif compare([o_a, n_a] ,[-1, 0]) == True:
                    replace_a = min( o_a, n_a )
                    temp_a.append( replace_a )
                else:
                    temp_a.append( o_a )

            combine_here = temp_a

        all_lfs_combined.append( combine_here )

    return all_lfs_combined

# %%
def grid_search(model_class,
                model_class_init,
                param_grid,
                train=None,
                dev=None,
                other_train=None,
                n_model_search=5,
                val_metric='f1_macro',
                seed=1234,
                checkpoint_gt_mv=False,
                tag_fmt_ckpnt='IO'):
    
    
    """Simple grid search helper function

    Parameters
    ----------
    model_class
    model_class_init
    param_grid
    train
    dev
    n_model_search
    val_metric
    seed

    Returns
    -------
    

    """
    
    
    L_train, Y_train = train
    L_dev, Y_dev = dev
    
    # sample configs
    params = sample_param_grid(param_grid, seed)[:n_model_search]
    
    defaults = {'seed': seed}
    best_score, best_config = 0.0, None
    print(f"Grid search over {len(params)} configs")
    
    for i, config in enumerate(params):
        print(f'[{i}] Label Model')
        config = dict(zip(param_grid.keys(), config))
        # update default params if not specified
        config.update({param: value for param, value in defaults.items() if param not in config})

        model = model_class(**model_class_init)
        model.fit(L_train, Y_dev, **config)
        
        y_pred = model.predict(L_dev)
        
        # set gold tags for evaluation
        if tag_fmt_ckpnt == 'IO':
            y_gold = np.array([0 if y == 0 else 1 for y in Y_dev])
        else:
            y_gold = Y_dev
            
            
        if -1 in y_pred:
            print("Label model predicted -1 (TODO: this happens inconsistently)")
            continue
            
        # use internal label model scorer to score the prediction
        metrics = model.score(L=L_dev,
                              Y=y_gold,
                              metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
                              tie_break_policy='random')
        
    
        # compare learned model against MV on same labeled dev set
        # skip if LM less than MV
        if checkpoint_gt_mv:
            mv_metrics = model.score(L=L_dev,
                                  Y=y_gold,
                                  metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
                                  tie_break_policy='random')

            if metrics[val_metric] < mv_metrics[val_metric]:
                continue
                
        if not best_score or metrics[val_metric] > best_score[val_metric]:
            print(config)
            best_score = metrics
            best_config = config
            
            # print training set score if we have labeled data
            if np.any(Y_train):
                y_pred = model.predict(L_train)

                if tag_fmt_ckpnt == 'IO':
                    y_gold = np.array([0 if y == 0 else 1 for y in Y_train])
                else:
                    y_gold = Y_train

                metrics = model.score(L=L_train,
                                      Y=y_gold,
                                      metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
                                      tie_break_policy='random')

                print('[TRAIN] {}'.format(' | '.join([f'{m}: {v * 100:2.2f}' for m, v in metrics.items()])))

            print('[DEV]   {}'.format(' | '.join([f'{m}: {v * 100:2.2f}' for m, v in best_score.items()])))
            print('-' * 88)
            
            
    # retrain best model
    print('BEST')
    print(best_config)
    model = model_class(**model_class_init)
    
    
    model.fit(L_train, Y_dev, **best_config)
    return model, best_config, best_score

# %%
def train(partitioned_d_umls, umls_d, non_umls_d, ds_d, heur_d, dict_d, df_data_train, df_data_val, picos, paramgrid):
   

    best_f1_macro = 0.0
    best_overall_model = ''
    best_overall_config = ''
    
    
    model_class_init = {
        'cardinality': 2, 
        'verbose': True
    }

    num_hyperparams = functools.reduce(lambda x,y:x*y, [len(x) for x in param_grid.values()])
    print("Hyperparamater Search Space:", num_hyperparams)
    n_model_search = 25
    


    '''#########################################################################
    # Choosing the number of LF's from UMLS all
    #########################################################################'''
    
    for i, partition in enumerate(partitioned_d_umls):
        
        if len( partition ) >= 40:

            combined_lf = getLFs(partition, umls_d, len(Y_tokens))
            assert len(partition) == len(combined_lf)

            print( 'Total number of UMLS partitions: ', len(partition) )
            combined_lf.extend( list(non_umls_d.values()) ) # Combine with level 2
            combined_lf.extend( list(ds_d.values()) ) # Combine with level 3
            combined_lf.extend( list(heur_d.values()) ) # Combine with level 4
            combined_lf.extend( list(dict_d.values()) ) # combine with level 4

            L = np.array(combined_lf)
            L = np.transpose(L)
            L_train, L_val = train_test_split(L, test_size=0.20, shuffle=False)

            Y_train = df_data_train[picos]
            Y_val = df_data_val[picos]


            best_model, best_config, best_score = grid_search(LMsnorkel, 
                                               model_class_init, 
                                               paramgrid,
                                               train = (L_train, Y_train),
                                               dev = (L_val, Y_val),
                                               n_model_search=n_model_search, 
                                               val_metric='f1_macro', 
                                               seed=1234,
                                               tag_fmt_ckpnt='IO')

            if best_score['f1_macro'] > best_f1_macro:
                best_f1_macro = best_score['f1_macro']
                best_overall_model = best_model
                best_overall_config = best_config


            print('Best overall macro F1 score: ', best_f1_macro)
            print('Best overall configuration: ', best_overall_config)

# %%
param_grid = {
    'lr': [0.001, 0.0001],
    'l2': [0.001, 0.0001],
    'n_epochs': [50, 100, 200, 600, 700, 1000, 2000],
    'prec_init': [0.6, 0.7, 0.8, 0.9],
    'optimizer': ["adamax", "adam", "sgd"],
    'lr_scheduler': ['constant'],
}

# %%
train(partitioned_p_umls, umls_p, nonumls_p, ds_p, heur_p, dict_p, df_data_train, df_data_val, 'p', paramgrid = param_grid)
# Out:
# Hyperparamater Search Space: 336
# Total number of UMLS partitions:  1
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.89 | precision: 0.00 | recall: 0.00 | f1: 0.00 | f1_macro: 46.78
# [DEV]   accuracy: 87.70 | precision: 0.00 | recall: 0.00 | f1: 0.00 | f1_macro: 46.72
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.05 | precision: 32.19 | recall: 6.29 | f1: 10.52 | f1_macro: 51.77
# [DEV]   accuracy: 86.93 | precision: 33.68 | recall: 6.46 | f1: 10.84 | f1_macro: 51.89
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.21 | precision: 24.33 | recall: 10.51 | f1: 14.67 | f1_macro: 53.29
# [DEV]   accuracy: 85.14 | precision: 25.40 | recall: 10.73 | f1: 15.09 | f1_macro: 53.47
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  2
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.95 | precision: 74.77 | recall: 0.76 | f1: 1.50 | f1_macro: 47.54
# [DEV]   accuracy: 87.78 | precision: 74.09 | recall: 0.98 | f1: 1.93 | f1_macro: 47.71
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.04 | precision: 32.14 | recall: 6.32 | f1: 10.57 | f1_macro: 51.79
# [DEV]   accuracy: 86.91 | precision: 33.44 | recall: 6.50 | f1: 10.88 | f1_macro: 51.91
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.18 | precision: 24.24 | recall: 10.54 | f1: 14.69 | f1_macro: 53.29
# [DEV]   accuracy: 85.10 | precision: 25.22 | recall: 10.76 | f1: 15.08 | f1_macro: 53.46
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.33 | precision: 24.86 | recall: 10.45 | f1: 14.71 | f1_macro: 53.35
# [DEV]   accuracy: 85.25 | precision: 25.81 | recall: 10.65 | f1: 15.07 | f1_macro: 53.50
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  3
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.89 | precision: 49.11 | recall: 0.90 | f1: 1.77 | f1_macro: 47.66
# [DEV]   accuracy: 87.74 | precision: 58.27 | recall: 1.15 | f1: 2.26 | f1_macro: 47.86
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.15 | precision: 33.45 | recall: 6.21 | f1: 10.48 | f1_macro: 51.78
# [DEV]   accuracy: 87.01 | precision: 34.70 | recall: 6.36 | f1: 10.75 | f1_macro: 51.87
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.33 | precision: 24.96 | recall: 10.55 | f1: 14.83 | f1_macro: 53.40
# [DEV]   accuracy: 85.25 | precision: 25.92 | recall: 10.74 | f1: 15.19 | f1_macro: 53.55
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.12 | precision: 28.56 | recall: 9.75 | f1: 14.53 | f1_macro: 53.49
# [DEV]   accuracy: 86.04 | precision: 29.82 | recall: 10.01 | f1: 14.98 | f1_macro: 53.69
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  4
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.93 | precision: 56.04 | recall: 1.41 | f1: 2.76 | f1_macro: 48.16
# [DEV]   accuracy: 87.79 | precision: 62.34 | recall: 1.74 | f1: 3.39 | f1_macro: 48.44
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.22 | precision: 34.59 | recall: 6.17 | f1: 10.48 | f1_macro: 51.80
# [DEV]   accuracy: 87.10 | precision: 36.13 | recall: 6.41 | f1: 10.89 | f1_macro: 51.97
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.17 | precision: 24.36 | recall: 10.68 | f1: 14.85 | f1_macro: 53.36
# [DEV]   accuracy: 85.10 | precision: 25.42 | recall: 10.93 | f1: 15.29 | f1_macro: 53.56
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.12 | precision: 28.60 | recall: 9.79 | f1: 14.59 | f1_macro: 53.52
# [DEV]   accuracy: 86.04 | precision: 29.94 | recall: 10.08 | f1: 15.08 | f1_macro: 53.74
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  5
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.95 | precision: 60.15 | recall: 1.46 | f1: 2.85 | f1_macro: 48.21
# [DEV]   accuracy: 87.80 | precision: 65.48 | recall: 1.71 | f1: 3.33 | f1_macro: 48.41
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.37 | precision: 36.73 | recall: 5.89 | f1: 10.15 | f1_macro: 51.68
# [DEV]   accuracy: 87.24 | precision: 38.17 | recall: 6.09 | f1: 10.50 | f1_macro: 51.82
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.31 | precision: 24.92 | recall: 10.60 | f1: 14.87 | f1_macro: 53.42
# [DEV]   accuracy: 85.23 | precision: 25.95 | recall: 10.83 | f1: 15.28 | f1_macro: 53.60
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.37 | precision: 29.78 | recall: 9.26 | f1: 14.12 | f1_macro: 53.36
# [DEV]   accuracy: 86.30 | precision: 31.36 | recall: 9.59 | f1: 14.68 | f1_macro: 53.62
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  6
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.96 | precision: 58.45 | recall: 2.01 | f1: 3.89 | f1_macro: 48.73
# [DEV]   accuracy: 87.80 | precision: 60.50 | recall: 2.27 | f1: 4.37 | f1_macro: 48.93
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.36 | precision: 36.68 | recall: 6.06 | f1: 10.41 | f1_macro: 51.80
# [DEV]   accuracy: 87.22 | precision: 38.14 | recall: 6.28 | f1: 10.78 | f1_macro: 51.95
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.28 | precision: 24.89 | recall: 10.66 | f1: 14.93 | f1_macro: 53.44
# [DEV]   accuracy: 85.21 | precision: 25.88 | recall: 10.87 | f1: 15.31 | f1_macro: 53.61
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.36 | precision: 29.77 | recall: 9.32 | f1: 14.19 | f1_macro: 53.39
# [DEV]   accuracy: 86.28 | precision: 31.27 | recall: 9.63 | f1: 14.72 | f1_macro: 53.63
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 77.83 | precision: 20.20 | recall: 28.16 | f1: 23.53 | f1_macro: 55.28
# [DEV]   accuracy: 77.83 | precision: 20.68 | recall: 28.31 | f1: 23.90 | f1_macro: 55.46
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5546359155547094
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  7
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.96 | precision: 58.47 | recall: 1.96 | f1: 3.79 | f1_macro: 48.68
# [DEV]   accuracy: 87.80 | precision: 60.41 | recall: 2.22 | f1: 4.28 | f1_macro: 48.88
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.42 | precision: 36.29 | recall: 5.17 | f1: 9.04 | f1_macro: 51.14
# [DEV]   accuracy: 87.27 | precision: 37.49 | recall: 5.26 | f1: 9.23 | f1_macro: 51.19
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.29 | precision: 24.94 | recall: 10.70 | f1: 14.97 | f1_macro: 53.46
# [DEV]   accuracy: 85.21 | precision: 25.95 | recall: 10.93 | f1: 15.38 | f1_macro: 53.64
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 78.16 | precision: 20.46 | recall: 27.83 | f1: 23.59 | f1_macro: 55.42
# [DEV]   accuracy: 78.16 | precision: 21.00 | recall: 28.07 | f1: 24.02 | f1_macro: 55.64
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5563723880508407
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  8
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.96 | precision: 59.67 | recall: 1.80 | f1: 3.49 | f1_macro: 48.54
# [DEV]   accuracy: 87.79 | precision: 61.29 | recall: 2.05 | f1: 3.97 | f1_macro: 48.73
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.59 | precision: 39.87 | recall: 4.81 | f1: 8.58 | f1_macro: 50.96
# [DEV]   accuracy: 87.48 | precision: 42.26 | recall: 4.93 | f1: 8.83 | f1_macro: 51.05
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.29 | precision: 24.94 | recall: 10.69 | f1: 14.97 | f1_macro: 53.46
# [DEV]   accuracy: 85.21 | precision: 25.95 | recall: 10.92 | f1: 15.38 | f1_macro: 53.64
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.87 | precision: 21.89 | recall: 25.78 | f1: 23.68 | f1_macro: 56.04
# [DEV]   accuracy: 79.95 | precision: 22.59 | recall: 25.97 | f1: 24.16 | f1_macro: 56.31
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  9
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.89 | precision: 50.84 | recall: 0.92 | f1: 1.81 | f1_macro: 47.68
# [DEV]   accuracy: 87.74 | precision: 58.22 | recall: 1.12 | f1: 2.19 | f1_macro: 47.83
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.68 | precision: 41.57 | recall: 4.19 | f1: 7.61 | f1_macro: 50.50
# [DEV]   accuracy: 87.53 | precision: 43.21 | recall: 4.38 | f1: 7.96 | f1_macro: 50.64
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.05 | precision: 28.30 | recall: 9.89 | f1: 14.65 | f1_macro: 53.53
# [DEV]   accuracy: 85.97 | precision: 29.57 | recall: 10.20 | f1: 15.17 | f1_macro: 53.76
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.87 | precision: 21.89 | recall: 25.78 | f1: 23.68 | f1_macro: 56.04
# [DEV]   accuracy: 79.95 | precision: 22.58 | recall: 25.97 | f1: 24.16 | f1_macro: 56.30
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  10
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.89 | precision: 50.54 | recall: 1.14 | f1: 2.23 | f1_macro: 47.89
# [DEV]   accuracy: 87.73 | precision: 55.40 | recall: 1.31 | f1: 2.56 | f1_macro: 48.01
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.64 | precision: 40.52 | recall: 4.48 | f1: 8.07 | f1_macro: 50.72
# [DEV]   accuracy: 87.48 | precision: 41.90 | recall: 4.67 | f1: 8.41 | f1_macro: 50.85
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.05 | precision: 28.37 | recall: 9.96 | f1: 14.74 | f1_macro: 53.57
# [DEV]   accuracy: 85.97 | precision: 29.66 | recall: 10.26 | f1: 15.24 | f1_macro: 53.80
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.87 | precision: 21.89 | recall: 25.78 | f1: 23.68 | f1_macro: 56.04
# [DEV]   accuracy: 79.95 | precision: 22.58 | recall: 25.97 | f1: 24.16 | f1_macro: 56.30
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  11
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.88 | precision: 48.58 | recall: 1.46 | f1: 2.84 | f1_macro: 48.19
# [DEV]   accuracy: 87.72 | precision: 52.17 | recall: 1.62 | f1: 3.15 | f1_macro: 48.30
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.62 | precision: 40.21 | recall: 4.56 | f1: 8.19 | f1_macro: 50.78
# [DEV]   accuracy: 87.47 | precision: 41.66 | recall: 4.73 | f1: 8.49 | f1_macro: 50.88
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.05 | precision: 28.36 | recall: 9.96 | f1: 14.74 | f1_macro: 53.57
# [DEV]   accuracy: 85.97 | precision: 29.66 | recall: 10.26 | f1: 15.25 | f1_macro: 53.80
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.87 | precision: 21.89 | recall: 25.78 | f1: 23.68 | f1_macro: 56.04
# [DEV]   accuracy: 79.95 | precision: 22.58 | recall: 25.96 | f1: 24.15 | f1_macro: 56.30
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  12
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.88 | precision: 49.08 | recall: 1.72 | f1: 3.32 | f1_macro: 48.43
# [DEV]   accuracy: 87.71 | precision: 50.68 | recall: 1.78 | f1: 3.44 | f1_macro: 48.44
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.38 | precision: 36.33 | recall: 5.64 | f1: 9.77 | f1_macro: 51.49
# [DEV]   accuracy: 87.17 | precision: 36.49 | recall: 5.79 | f1: 9.99 | f1_macro: 51.54
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.92 | precision: 28.07 | recall: 10.43 | f1: 15.21 | f1_macro: 53.76
# [DEV]   accuracy: 85.83 | precision: 29.13 | recall: 10.63 | f1: 15.58 | f1_macro: 53.92
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.83 | precision: 21.85 | recall: 25.83 | f1: 23.67 | f1_macro: 56.03
# [DEV]   accuracy: 79.89 | precision: 22.51 | recall: 26.01 | f1: 24.13 | f1_macro: 56.27
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  13
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.88 | precision: 49.18 | recall: 1.94 | f1: 3.74 | f1_macro: 48.64
# [DEV]   accuracy: 87.70 | precision: 50.22 | recall: 2.02 | f1: 3.88 | f1_macro: 48.66
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.24 | precision: 34.85 | recall: 6.22 | f1: 10.55 | f1_macro: 51.84
# [DEV]   accuracy: 87.04 | precision: 35.24 | recall: 6.44 | f1: 10.89 | f1_macro: 51.95
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.03 | precision: 24.56 | recall: 11.40 | f1: 15.57 | f1_macro: 53.68
# [DEV]   accuracy: 84.96 | precision: 25.54 | recall: 11.62 | f1: 15.97 | f1_macro: 53.86
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.80 | precision: 21.81 | recall: 25.85 | f1: 23.66 | f1_macro: 56.01
# [DEV]   accuracy: 79.85 | precision: 22.47 | recall: 26.05 | f1: 24.13 | f1_macro: 56.25
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  14
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.87 | precision: 47.57 | recall: 1.98 | f1: 3.81 | f1_macro: 48.67
# [DEV]   accuracy: 87.69 | precision: 48.65 | recall: 2.06 | f1: 3.94 | f1_macro: 48.68
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.03 | precision: 32.65 | recall: 6.66 | f1: 11.06 | f1_macro: 52.03
# [DEV]   accuracy: 86.84 | precision: 33.14 | recall: 6.86 | f1: 11.37 | f1_macro: 52.13
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.89 | precision: 24.20 | recall: 11.62 | f1: 15.70 | f1_macro: 53.70
# [DEV]   accuracy: 84.81 | precision: 25.12 | recall: 11.86 | f1: 16.11 | f1_macro: 53.88
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.69 | precision: 21.68 | recall: 25.92 | f1: 23.61 | f1_macro: 55.95
# [DEV]   accuracy: 79.72 | precision: 22.31 | recall: 26.13 | f1: 24.07 | f1_macro: 56.18
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  15
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.87 | precision: 48.30 | recall: 2.62 | f1: 4.98 | f1_macro: 49.25
# [DEV]   accuracy: 87.70 | precision: 49.92 | recall: 2.67 | f1: 5.06 | f1_macro: 49.24
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.78 | precision: 31.37 | recall: 7.69 | f1: 12.36 | f1_macro: 52.60
# [DEV]   accuracy: 86.63 | precision: 32.27 | recall: 7.91 | f1: 12.71 | f1_macro: 52.74
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.82 | precision: 24.12 | recall: 11.82 | f1: 15.86 | f1_macro: 53.76
# [DEV]   accuracy: 84.75 | precision: 25.00 | recall: 12.02 | f1: 16.23 | f1_macro: 53.92
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.68 | precision: 21.68 | recall: 25.93 | f1: 23.61 | f1_macro: 55.95
# [DEV]   accuracy: 79.72 | precision: 22.31 | recall: 26.14 | f1: 24.07 | f1_macro: 56.19
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  16
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.81 | precision: 45.38 | recall: 3.11 | f1: 5.82 | f1_macro: 49.66
# [DEV]   accuracy: 87.64 | precision: 46.31 | recall: 3.15 | f1: 5.89 | f1_macro: 49.64
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.31 | precision: 29.28 | recall: 9.23 | f1: 14.03 | f1_macro: 53.30
# [DEV]   accuracy: 86.16 | precision: 30.01 | recall: 9.44 | f1: 14.36 | f1_macro: 53.41
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.70 | precision: 24.08 | recall: 12.23 | f1: 16.22 | f1_macro: 53.90
# [DEV]   accuracy: 84.61 | precision: 24.86 | recall: 12.42 | f1: 16.56 | f1_macro: 54.04
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.65 | precision: 21.67 | recall: 26.02 | f1: 23.65 | f1_macro: 55.95
# [DEV]   accuracy: 79.68 | precision: 22.29 | recall: 26.24 | f1: 24.11 | f1_macro: 56.19
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  17
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.77 | precision: 43.47 | recall: 3.40 | f1: 6.31 | f1_macro: 49.88
# [DEV]   accuracy: 87.58 | precision: 43.62 | recall: 3.40 | f1: 6.31 | f1_macro: 49.83
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.28 | precision: 29.15 | recall: 9.28 | f1: 14.08 | f1_macro: 53.31
# [DEV]   accuracy: 86.13 | precision: 29.85 | recall: 9.48 | f1: 14.39 | f1_macro: 53.42
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.68 | precision: 24.03 | recall: 12.25 | f1: 16.23 | f1_macro: 53.90
# [DEV]   accuracy: 84.60 | precision: 24.85 | recall: 12.45 | f1: 16.59 | f1_macro: 54.05
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.65 | precision: 21.67 | recall: 26.02 | f1: 23.64 | f1_macro: 55.95
# [DEV]   accuracy: 79.68 | precision: 22.29 | recall: 26.24 | f1: 24.10 | f1_macro: 56.19
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  18
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.66 | precision: 40.79 | recall: 4.26 | f1: 7.71 | f1_macro: 50.55
# [DEV]   accuracy: 87.49 | precision: 41.78 | recall: 4.34 | f1: 7.87 | f1_macro: 50.58
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.14 | precision: 28.91 | recall: 9.93 | f1: 14.79 | f1_macro: 53.62
# [DEV]   accuracy: 85.96 | precision: 29.32 | recall: 10.02 | f1: 14.93 | f1_macro: 53.64
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.38 | precision: 23.29 | recall: 12.65 | f1: 16.40 | f1_macro: 53.89
# [DEV]   accuracy: 84.29 | precision: 24.05 | recall: 12.87 | f1: 16.76 | f1_macro: 54.04
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.54 | precision: 27.06 | recall: 11.45 | f1: 16.09 | f1_macro: 54.09
# [DEV]   accuracy: 85.43 | precision: 27.93 | recall: 11.71 | f1: 16.50 | f1_macro: 54.26
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.65 | precision: 21.67 | recall: 26.04 | f1: 23.65 | f1_macro: 55.96
# [DEV]   accuracy: 79.68 | precision: 22.29 | recall: 26.25 | f1: 24.11 | f1_macro: 56.19
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  19
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.71 | precision: 42.03 | recall: 3.93 | f1: 7.19 | f1_macro: 50.31
# [DEV]   accuracy: 87.54 | precision: 43.05 | recall: 4.05 | f1: 7.41 | f1_macro: 50.37
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.13 | precision: 28.90 | recall: 9.93 | f1: 14.78 | f1_macro: 53.62
# [DEV]   accuracy: 85.96 | precision: 29.30 | recall: 10.02 | f1: 14.93 | f1_macro: 53.64
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 84.53 | precision: 23.76 | recall: 12.57 | f1: 16.44 | f1_macro: 53.96
# [DEV]   accuracy: 84.43 | precision: 24.48 | recall: 12.76 | f1: 16.77 | f1_macro: 54.09
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.55 | precision: 27.04 | recall: 11.37 | f1: 16.01 | f1_macro: 54.05
# [DEV]   accuracy: 85.44 | precision: 27.95 | recall: 11.65 | f1: 16.44 | f1_macro: 54.23
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 79.65 | precision: 21.67 | recall: 26.04 | f1: 23.65 | f1_macro: 55.96
# [DEV]   accuracy: 79.67 | precision: 22.29 | recall: 26.25 | f1: 24.11 | f1_macro: 56.19
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# ...
# [DEV]   accuracy: 87.36 | precision: 41.11 | recall: 6.43 | f1: 11.12 | f1_macro: 52.16
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.46 | precision: 27.61 | recall: 12.40 | f1: 17.11 | f1_macro: 54.57
# [DEV]   accuracy: 85.36 | precision: 28.34 | recall: 12.47 | f1: 17.32 | f1_macro: 54.64
# ----------------------------------------------------------------------------------------
# [4] Label Model
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 78.17 | precision: 20.46 | recall: 27.80 | f1: 23.57 | f1_macro: 55.42
# [DEV]   accuracy: 78.17 | precision: 20.99 | recall: 28.04 | f1: 24.01 | f1_macro: 55.63
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  37
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.55 | precision: 40.80 | recall: 6.31 | f1: 10.93 | f1_macro: 52.12
# [DEV]   accuracy: 87.39 | precision: 41.68 | recall: 6.26 | f1: 10.88 | f1_macro: 52.05
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.70 | precision: 28.17 | recall: 11.66 | f1: 16.49 | f1_macro: 54.34
# [DEV]   accuracy: 85.61 | precision: 28.98 | recall: 11.72 | f1: 16.69 | f1_macro: 54.41
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.06 | precision: 21.91 | recall: 15.56 | f1: 18.20 | f1_macro: 54.38
# [DEV]   accuracy: 83.00 | precision: 22.49 | recall: 15.62 | f1: 18.44 | f1_macro: 54.48
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 78.17 | precision: 20.46 | recall: 27.80 | f1: 23.57 | f1_macro: 55.42
# [DEV]   accuracy: 78.17 | precision: 20.99 | recall: 28.04 | f1: 24.01 | f1_macro: 55.63
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  38
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.57 | precision: 41.13 | recall: 6.16 | f1: 10.72 | f1_macro: 52.02
# [DEV]   accuracy: 87.42 | precision: 42.01 | recall: 6.12 | f1: 10.68 | f1_macro: 51.96
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.73 | precision: 28.28 | recall: 11.64 | f1: 16.49 | f1_macro: 54.34
# [DEV]   accuracy: 85.62 | precision: 28.99 | recall: 11.67 | f1: 16.64 | f1_macro: 54.39
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.06 | precision: 21.91 | recall: 15.56 | f1: 18.20 | f1_macro: 54.38
# [DEV]   accuracy: 83.00 | precision: 22.49 | recall: 15.62 | f1: 18.44 | f1_macro: 54.48
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 78.17 | precision: 20.46 | recall: 27.80 | f1: 23.57 | f1_macro: 55.42
# [DEV]   accuracy: 78.17 | precision: 20.99 | recall: 28.04 | f1: 24.01 | f1_macro: 55.63
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  39
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.57 | precision: 40.77 | recall: 5.82 | f1: 10.18 | f1_macro: 51.75
# [DEV]   accuracy: 87.42 | precision: 41.82 | recall: 5.82 | f1: 10.21 | f1_macro: 51.73
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.78 | precision: 28.38 | recall: 11.45 | f1: 16.31 | f1_macro: 54.27
# [DEV]   accuracy: 85.68 | precision: 29.14 | recall: 11.50 | f1: 16.49 | f1_macro: 54.33
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.06 | precision: 21.91 | recall: 15.56 | f1: 18.20 | f1_macro: 54.38
# [DEV]   accuracy: 83.00 | precision: 22.49 | recall: 15.62 | f1: 18.44 | f1_macro: 54.48
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 78.17 | precision: 20.46 | recall: 27.80 | f1: 23.57 | f1_macro: 55.42
# [DEV]   accuracy: 78.17 | precision: 20.99 | recall: 28.04 | f1: 24.01 | f1_macro: 55.63
# ----------------------------------------------------------------------------------------
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5630576977845764
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 2000, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  40
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.58 | precision: 40.81 | recall: 5.78 | f1: 10.12 | f1_macro: 51.73
# [DEV]   accuracy: 87.43 | precision: 42.05 | recall: 5.81 | f1: 10.20 | f1_macro: 51.72
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.84 | precision: 28.60 | recall: 11.29 | f1: 16.19 | f1_macro: 54.23
# [DEV]   accuracy: 85.73 | precision: 29.34 | recall: 11.37 | f1: 16.39 | f1_macro: 54.29
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.10 | precision: 24.91 | recall: 19.65 | f1: 21.97 | f1_macro: 56.25
# [DEV]   accuracy: 83.05 | precision: 25.62 | recall: 19.88 | f1: 22.39 | f1_macro: 56.44
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5643631810708896
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  41
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.55 | precision: 40.78 | recall: 6.30 | f1: 10.92 | f1_macro: 52.11
# [DEV]   accuracy: 87.40 | precision: 41.71 | recall: 6.25 | f1: 10.88 | f1_macro: 52.05
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.71 | precision: 28.45 | recall: 11.92 | f1: 16.80 | f1_macro: 54.49
# [DEV]   accuracy: 85.62 | precision: 29.28 | recall: 11.97 | f1: 17.00 | f1_macro: 54.56
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.00 | precision: 24.96 | recall: 20.12 | f1: 22.28 | f1_macro: 56.37
# [DEV]   accuracy: 82.97 | precision: 25.72 | recall: 20.36 | f1: 22.73 | f1_macro: 56.58
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5658006919660654
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  42
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-4c5766eac930> in <module>
# ----> 1 train(partitioned_p_umls, umls_p, nonumls_p, ds_p, heur_p, dict_p, df_data_train, df_data_val, 'p', paramgrid = param_grid)
#
# <ipython-input-38-20b16337e44b> in train(partitioned_d_umls, umls_d, non_umls_d, ds_d, heur_d, dict_d, df_data_train, df_data_val, picos, paramgrid)
#      49                                            val_metric='f1_macro',
#      50                                            seed=1234,
# ---> 51                                            tag_fmt_ckpnt='IO')
#      52
#      53         if best_score['f1_macro'] > best_f1_macro:
#
# <ipython-input-31-a654398ce09d> in grid_search(model_class, model_class_init, param_grid, train, dev, other_train, n_model_search, val_metric, seed, checkpoint_gt_mv, tag_fmt_ckpnt)
#      99                                       Y=y_gold,
#     100                                       metrics=['accuracy', 'precision', 'recall', 'f1', 'f1_macro'],
# --> 101                                       tie_break_policy=0)
#     102
#     103                 print('[TRAIN] {}'.format(' | '.join([f'{m}: {v * 100:2.2f}' for m, v in metrics.items()])))
#
# ~/pico/lib/python3.6/site-packages/snorkel/labeling/model/label_model.py in score(self, L, Y, metrics, tie_break_policy)
#     507         {'f1': 0.8}
#     508         """
# --> 509         return super(LabelModel, self).score(L, Y, metrics, tie_break_policy)
#     510
#     511     # These loss functions get all their data directly from the LabelModel
#
# ~/pico/lib/python3.6/site-packages/snorkel/labeling/model/base_labeler.py in score(self, L, Y, metrics, tie_break_policy)
#     104
#     105         Y_pred, Y_prob = self.predict(
# --> 106             L, return_probs=True, tie_break_policy=tie_break_policy
#     107         )
#     108
#
# ~/pico/lib/python3.6/site-packages/snorkel/labeling/model/label_model.py in predict(self, L, return_probs, tie_break_policy)
#     464         array([0, 1, 0])
#     465         """
# --> 466         return super(LabelModel, self).predict(L, return_probs, tie_break_policy)
#     467
#     468     def score(
#
# ~/pico/lib/python3.6/site-packages/snorkel/labeling/model/base_labeler.py in predict(self, L, return_probs, tie_break_policy)
#      67         """
#      68         Y_probs = self.predict_proba(L)
# ---> 69         Y_p = probs_to_preds(Y_probs, tie_break_policy)
#      70         if return_probs:
#      71             return Y_p, Y_probs
#
# ~/pico/lib/python3.6/site-packages/snorkel/utils/core.py in probs_to_preds(probs, tie_break_policy, tol)
#      68         else:
#      69             raise ValueError(
# ---> 70                 f"tie_break_policy={tie_break_policy} policy not recognized."
#      71             )
#      72     return Y_pred.astype(np.int)
#
# ValueError: tie_break_policy=0 policy not recognized.

# %%
train(partitioned_i_umls, umls_i, nonumls_i, ds_i, heur_i, dict_i, df_data_train, df_data_val, 'i', paramgrid = param_grid)

# %%
train(partitioned_o_umls, umls_o, nonumls_o, ds_o, heur_o, dict_o, df_data_train, df_data_val, 'o', paramgrid = param_grid)

# %%
train(partitioned_p_umls, umls_p, nonumls_p, ds_p, heur_p, dict_p, df_data_train, df_data_val, 'p', paramgrid = param_grid)
# Out:
# Hyperparamater Search Space: 336
# Total number of UMLS partitions:  40
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.58 | precision: 40.81 | recall: 5.78 | f1: 10.12 | f1_macro: 51.73
# [DEV]   accuracy: 87.43 | precision: 42.05 | recall: 5.81 | f1: 10.20 | f1_macro: 51.72
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.84 | precision: 28.60 | recall: 11.29 | f1: 16.19 | f1_macro: 54.23
# [DEV]   accuracy: 85.73 | precision: 29.34 | recall: 11.37 | f1: 16.39 | f1_macro: 54.29
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.10 | precision: 24.91 | recall: 19.65 | f1: 21.97 | f1_macro: 56.25
# [DEV]   accuracy: 83.05 | precision: 25.62 | recall: 19.88 | f1: 22.39 | f1_macro: 56.44
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5643631810708896
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  41
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.55 | precision: 40.78 | recall: 6.30 | f1: 10.92 | f1_macro: 52.11
# [DEV]   accuracy: 87.40 | precision: 41.71 | recall: 6.25 | f1: 10.88 | f1_macro: 52.05
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.71 | precision: 28.45 | recall: 11.92 | f1: 16.80 | f1_macro: 54.49
# [DEV]   accuracy: 85.62 | precision: 29.28 | recall: 11.97 | f1: 17.00 | f1_macro: 54.56
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.00 | precision: 24.96 | recall: 20.12 | f1: 22.28 | f1_macro: 56.37
# [DEV]   accuracy: 82.97 | precision: 25.72 | recall: 20.36 | f1: 22.73 | f1_macro: 56.58
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5658006919660654
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  42
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.57 | precision: 41.13 | recall: 6.18 | f1: 10.75 | f1_macro: 52.04
# [DEV]   accuracy: 87.41 | precision: 41.92 | recall: 6.11 | f1: 10.66 | f1_macro: 51.94
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.75 | precision: 28.46 | recall: 11.70 | f1: 16.58 | f1_macro: 54.39
# [DEV]   accuracy: 85.66 | precision: 29.31 | recall: 11.78 | f1: 16.80 | f1_macro: 54.48
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.00 | precision: 24.96 | recall: 20.12 | f1: 22.28 | f1_macro: 56.37
# [DEV]   accuracy: 82.97 | precision: 25.72 | recall: 20.36 | f1: 22.73 | f1_macro: 56.58
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5658006919660654
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  43
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.52 | precision: 40.41 | recall: 6.38 | f1: 11.02 | f1_macro: 52.16
# [DEV]   accuracy: 87.38 | precision: 41.56 | recall: 6.37 | f1: 11.05 | f1_macro: 52.13
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.83 | precision: 28.07 | recall: 10.91 | f1: 15.71 | f1_macro: 53.99
# [DEV]   accuracy: 85.72 | precision: 28.82 | recall: 10.95 | f1: 15.88 | f1_macro: 54.04
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.80 | precision: 24.64 | recall: 20.43 | f1: 22.34 | f1_macro: 56.33
# [DEV]   accuracy: 82.80 | precision: 25.46 | recall: 20.68 | f1: 22.82 | f1_macro: 56.57
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.00 | precision: 24.95 | recall: 20.09 | f1: 22.26 | f1_macro: 56.36
# [DEV]   accuracy: 82.97 | precision: 25.70 | recall: 20.35 | f1: 22.71 | f1_macro: 56.57
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5658006919660654
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  44
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.57 | precision: 41.16 | recall: 6.23 | f1: 10.82 | f1_macro: 52.07
# [DEV]   accuracy: 87.42 | precision: 42.21 | recall: 6.19 | f1: 10.79 | f1_macro: 52.01
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.87 | precision: 28.26 | recall: 10.86 | f1: 15.68 | f1_macro: 53.99
# [DEV]   accuracy: 85.76 | precision: 28.95 | recall: 10.88 | f1: 15.81 | f1_macro: 54.02
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.80 | precision: 24.65 | recall: 20.43 | f1: 22.35 | f1_macro: 56.34
# [DEV]   accuracy: 82.81 | precision: 25.47 | recall: 20.67 | f1: 22.82 | f1_macro: 56.57
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.00 | precision: 24.95 | recall: 20.09 | f1: 22.26 | f1_macro: 56.36
# [DEV]   accuracy: 82.97 | precision: 25.70 | recall: 20.35 | f1: 22.71 | f1_macro: 56.57
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5658006919660654
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  45
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.58 | precision: 41.23 | recall: 6.06 | f1: 10.57 | f1_macro: 51.95
# [DEV]   accuracy: 87.43 | precision: 42.19 | recall: 6.05 | f1: 10.59 | f1_macro: 51.91
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.87 | precision: 28.26 | recall: 10.85 | f1: 15.68 | f1_macro: 53.99
# [DEV]   accuracy: 85.76 | precision: 28.94 | recall: 10.87 | f1: 15.80 | f1_macro: 54.01
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.79 | precision: 24.64 | recall: 20.46 | f1: 22.36 | f1_macro: 56.34
# [DEV]   accuracy: 82.80 | precision: 25.46 | recall: 20.69 | f1: 22.83 | f1_macro: 56.57
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.01 | precision: 24.96 | recall: 20.09 | f1: 22.26 | f1_macro: 56.36
# [DEV]   accuracy: 82.97 | precision: 25.71 | recall: 20.35 | f1: 22.72 | f1_macro: 56.58
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5658006919660654
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  46
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.60 | precision: 41.87 | recall: 6.28 | f1: 10.92 | f1_macro: 52.13
# [DEV]   accuracy: 87.44 | precision: 42.82 | recall: 6.23 | f1: 10.88 | f1_macro: 52.06
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.95 | precision: 29.22 | recall: 11.26 | f1: 16.26 | f1_macro: 54.29
# [DEV]   accuracy: 85.83 | precision: 29.82 | recall: 11.26 | f1: 16.35 | f1_macro: 54.30
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.79 | precision: 24.75 | recall: 20.64 | f1: 22.51 | f1_macro: 56.41
# [DEV]   accuracy: 82.80 | precision: 25.59 | recall: 20.88 | f1: 23.00 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.01 | precision: 25.07 | recall: 20.27 | f1: 22.41 | f1_macro: 56.44
# [DEV]   accuracy: 82.98 | precision: 25.85 | recall: 20.54 | f1: 22.89 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5666423309973397
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  47
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.58 | precision: 40.90 | recall: 5.76 | f1: 10.09 | f1_macro: 51.71
# [DEV]   accuracy: 87.44 | precision: 42.14 | recall: 5.80 | f1: 10.20 | f1_macro: 51.72
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.98 | precision: 29.30 | recall: 11.18 | f1: 16.19 | f1_macro: 54.27
# [DEV]   accuracy: 85.85 | precision: 29.88 | recall: 11.19 | f1: 16.28 | f1_macro: 54.27
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.80 | precision: 24.76 | recall: 20.63 | f1: 22.50 | f1_macro: 56.41
# [DEV]   accuracy: 82.80 | precision: 25.59 | recall: 20.87 | f1: 22.99 | f1_macro: 56.65
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.01 | precision: 25.07 | recall: 20.27 | f1: 22.41 | f1_macro: 56.44
# [DEV]   accuracy: 82.98 | precision: 25.85 | recall: 20.54 | f1: 22.89 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5666453810114611
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  48
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.59 | precision: 40.95 | recall: 5.67 | f1: 9.96 | f1_macro: 51.65
# [DEV]   accuracy: 87.44 | precision: 42.21 | recall: 5.70 | f1: 10.05 | f1_macro: 51.65
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 85.98 | precision: 29.31 | recall: 11.18 | f1: 16.19 | f1_macro: 54.27
# [DEV]   accuracy: 85.85 | precision: 29.88 | recall: 11.16 | f1: 16.26 | f1_macro: 54.26
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.79 | precision: 24.75 | recall: 20.64 | f1: 22.51 | f1_macro: 56.41
# [DEV]   accuracy: 82.80 | precision: 25.59 | recall: 20.87 | f1: 22.99 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.01 | precision: 25.07 | recall: 20.27 | f1: 22.41 | f1_macro: 56.44
# [DEV]   accuracy: 82.98 | precision: 25.85 | recall: 20.53 | f1: 22.89 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5666453810114611
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  49
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.60 | precision: 41.13 | recall: 5.56 | f1: 9.80 | f1_macro: 51.57
# [DEV]   accuracy: 87.45 | precision: 42.33 | recall: 5.63 | f1: 9.94 | f1_macro: 51.60
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.02 | precision: 29.49 | recall: 11.07 | f1: 16.10 | f1_macro: 54.24
# [DEV]   accuracy: 85.90 | precision: 30.10 | recall: 11.11 | f1: 16.23 | f1_macro: 54.26
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.79 | precision: 24.75 | recall: 20.64 | f1: 22.51 | f1_macro: 56.41
# [DEV]   accuracy: 82.80 | precision: 25.59 | recall: 20.87 | f1: 22.99 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
# [10] Label Model
# [11] Label Model
# [12] Label Model
# [13] Label Model
# [14] Label Model
# [15] Label Model
# [16] Label Model
# [17] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 83.01 | precision: 25.07 | recall: 20.27 | f1: 22.41 | f1_macro: 56.44
# [DEV]   accuracy: 82.99 | precision: 25.85 | recall: 20.53 | f1: 22.89 | f1_macro: 56.66
# ----------------------------------------------------------------------------------------
# [18] Label Model
# [19] Label Model
# [20] Label Model
# [21] Label Model
# [22] Label Model
# [23] Label Model
# [24] Label Model
# BEST
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Best overall macro F1 score:  0.5666453810114611
# Best overall configuration:  {'lr': 0.001, 'l2': 0.001, 'n_epochs': 1000, 'prec_init': 0.8, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# Total number of UMLS partitions:  50
# Grid search over 25 configs
# [0] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 200, 'prec_init': 0.8, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 87.61 | precision: 41.60 | recall: 5.78 | f1: 10.15 | f1_macro: 51.75
# [DEV]   accuracy: 87.48 | precision: 43.19 | recall: 5.83 | f1: 10.27 | f1_macro: 51.77
# ----------------------------------------------------------------------------------------
# [1] Label Model
# [2] Label Model
# [3] Label Model
# {'lr': 0.001, 'l2': 0.0001, 'n_epochs': 700, 'prec_init': 0.9, 'optimizer': 'adamax', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 86.04 | precision: 29.95 | recall: 11.38 | f1: 16.50 | f1_macro: 54.44
# [DEV]   accuracy: 85.93 | precision: 30.63 | recall: 11.41 | f1: 16.63 | f1_macro: 54.47
# ----------------------------------------------------------------------------------------
# [4] Label Model
# {'lr': 0.001, 'l2': 0.001, 'n_epochs': 600, 'prec_init': 0.6, 'optimizer': 'adam', 'lr_scheduler': 'constant', 'seed': 1234}
# [TRAIN] accuracy: 82.80 | precision: 24.89 | recall: 20.82 | f1: 22.67 | f1_macro: 56.50
# [DEV]   accuracy: 82.81 | precision: 25.74 | recall: 21.08 | f1: 23.18 | f1_macro: 56.75
# ----------------------------------------------------------------------------------------
# [5] Label Model
# [6] Label Model
# [7] Label Model
# [8] Label Model
# [9] Label Model
