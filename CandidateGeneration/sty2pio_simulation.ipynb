# %% [markdown]
# # Map semantic category to PIO

# %%
from os import listdir
from os.path import isfile, join
import pandas as pd
import ast
import json

from sklearn.metrics import f1_score, classification_report, recall_score, confusion_matrix

# %%
#indir_path = '/mnt/nas2/results/Results/systematicReview/distant_pico/semantic_to_target/training_ebm_candidate_generation'
indir_path = '/mnt/nas2/results/Results/systematicReview/distant_pico/semantic_to_target/val_studytype_candidate_generation'

# %%
data_files = [f for f in listdir(indir_path) if isfile(join(indir_path, f))]

# %%
len(data_files)
# Out:
# 127

# %%
semantic_type_labels = dict()

for eachSemantic in data_files:
    read_umls = f'{indir_path}/{eachSemantic}'
    sem_lf_data = pd.read_csv(read_umls, sep='\t')
    
    #flatten the labels
    labels_f = [ int(lab) for index, value in sem_lf_data.labels.items() for lab in ast.literal_eval(value) ]
    
    semantic_type_labels[ str(eachSemantic).replace('.tsv', '').replace('lf_','') ] = labels_f

# %%
print( 'Number of semantic type LFs loaded: ', len(semantic_type_labels) )
# Out:
# Number of semantic type LFs loaded:  127

# %% [markdown]
# ### What semantic types are suitable for an entity?

# %%
data_files[0]
# Out:
# 'lf_Language.tsv'

# %%
indir_path
# Out:
# '/mnt/nas2/results/Results/systematicReview/distant_pico/semantic_to_target/training_ebm_candidate_generation'

# %%
def getHandLabelled(picos, reverse:bool):
    
    infile = f'{indir_path}/{data_files[0]}'
    data_df = pd.read_csv(infile, sep='\t')    
    
    if picos == 'p':
        labels_f = [ int(lab) for index, value in sem_lf_data.p.items() for lab in ast.literal_eval(value) ]       
        
    if picos == 'i':
        labels_f = [ int(lab) for index, value in sem_lf_data.i.items() for lab in ast.literal_eval(value) ]
        
    if picos == 'o':
        labels_f = [ int(lab) for index, value in sem_lf_data.o.items() for lab in ast.literal_eval(value) ]
        
    if picos == 's':
        labels_f = [ int(lab) for index, value in sem_lf_data.s.items() for lab in ast.literal_eval(value) ]

    if reverse == True:
        labels_f = [ 1 if l==0 else 0 for l in labels_f ]
    else:
        labels_f = [ 1 if l>0 else 0 for l in labels_f ]
        
    return labels_f

# %%
reverse = False
#entity = 'p'
#labels_gt_p = getHandLabelled('p', reverse = reverse)
#labels_gt_i = getHandLabelled('i', reverse = reverse)
#labels_gt_o = getHandLabelled('o', reverse = reverse)
labels_gt_s = getHandLabelled('s', reverse = reverse)

# %%
def getHandLabelled_studytype(reverse:bool):
    
    infile = f'/mnt/nas2/data/systematicReview/PICO_datasets/StudyType/val_studytype.json'
    
    flattened_labs = []
    flattened_toks = []
    
    with open(infile, 'r') as rf:
        data_s = json.load(rf)
        
        for k,v in data_s.items():
            data = data_s[k]
            s_labs = data['studytype_fine']
            flattened_labs.extend( s_labs )
            s_toks = data['tokens']
            flattened_toks.extend( s_toks )


    if reverse == True:
        flattened_labs = [ 1 if l==0 else 0 for l in flattened_labs ]
    else:
        flattened_labs = [ 1 if l>0 else 0 for l in flattened_labs ]
        
    return flattened_toks, flattened_labs

# %%
#tokens_gt_s , labels_gt_s = getHandLabelled_studytype(reverse = reverse)

# %%
print(sum(labels_gt_p))
print(sum(labels_gt_i))
print(sum(labels_gt_o))
print(sum(labels_gt_s))
# Out:
# 164591
# 125960
# 155722
# 4650

# %%
len(semantic_type_labels['Language'])
# Out:
# 211870

# %%
def getMetrics(sem_labs, gt):

    r = []
    f1_all = []
    #tp_all = []

    for k,v in sem_labs.items():
        
        

        #f1 score
        f1 = f1_score(gt, v, average='binary',pos_label=1)
        f1 = f1 * 100
        f1_all.append( f1 )

        #Recall score
        recall = recall_score(gt, v, average='binary',pos_label=1)
        recall = recall * 100   
        r.append( recall )
        
        print(k, ' - - ', recall)
        
        
    assert len(r) == len(f1_all) == len( list(sem_labs.keys()) )


    metrics_df = pd.DataFrame(
        {'STY': list(sem_labs.keys()),
         'f1': f1_all,
         'R': r
        })
        
    return metrics_df

# %%
metrics_df_p = getMetrics(semantic_type_labels, labels_gt_p)
# Out:
# Language  - -  0.1458159923689631
# Anatomical_Structure  - -  0.07047772964499881
# Patient_or_Disabled_Group  - -  4.510574697279924
# Organism_Function  - -  0.5376964718605514
# Body_Location_or_Region  - -  1.1890079044419197
# Archaeon  - -  0.007898366253318833
# Chemical_Viewed_Functionally  - -  0.057111263677843874
# Mammal  - -  0.2849487517543487
# Nucleic_Acid_Nucleoside_or_Nucleotide  - -  0.047390197519913
# Disease_or_Syndrome  - -  6.606679587583768
# Organism_Attribute  - -  0.8366192562169256
# Spatial_Concept  - -  2.8185016191650822
# Medical_Device  - -  0.9405131507798118
# Element_Ion_or_Isotope  - -  0.05285829723374911
# Injury_or_Poisoning  - -  0.5091408400216294
# Inorganic_Chemical  - -  0.12272846024387724
# Food  - -  0.20961048903038443
# Social_Behavior  - -  0.3062135839748224
# Occupational_Activity  - -  0.23512828769495295
# Fully_Formed_Anatomical_Structure  - -  0.06075666348706795
# Laboratory_Procedure  - -  1.014028713599164
# Group  - -  0.8894775534506747
# Clinical_Drug  - -  0.035846431457370084
# Nucleotide_Sequence  - -  0.037061564727111446
# Age_Group  - -  1.929631632349278
# Amino_Acid_Peptide_or_Protein  - -  0.6507038659464978
# Hazardous_or_Poisonous_Substance  - -  0.10207119465827416
# Tissue  - -  0.3918804794915883
# Manufactured_Object  - -  2.0669416918300514
# Governmental_or_Regulatory_Activity  - -  0.1063241611023689
# Mental_Process  - -  0.7655339599370561
# Congenital_Abnormality  - -  0.07898366253318834
# Pharmacologic_Substance  - -  2.8908020487146926
# Educational_Activity  - -  0.8821867538322266
# Human-caused_Phenomenon_or_Process  - -  0.046782630885042316
# Organism  - -  3.814910900352996
# Laboratory_or_Test_Result  - -  0.5626067038902491
# Clinical_Attribute  - -  8.097040542921546
# Eukaryote  - -  0.8742883875789077
# Pathologic_Function  - -  1.1045561421948953
# Machine_Activity  - -  0.0917425618654726
# Drug_Delivery_Device  - -  0.0012151332697413588
# Research_Activity  - -  1.984312629487639
# Amphibian  - -  0.007290799618448153
# Conceptual_Entity  - -  3.081577972064086
# Diagnostic_Procedure  - -  1.313559064590409
# Cell_Component  - -  0.2679368859779696
# Receptor  - -  0.08991986196086056
# Embryonic_Structure  - -  0.01944213231586174
# Fungus  - -  0.01093619942767223
# Reptile  - -  0.004252966444094756
# Family_Group  - -  1.32328013074834
# Geographic_Area  - -  0.6756140979761955
# Bacterium  - -  0.06440206329629201
# Therapeutic_or_Preventive_Procedure  - -  4.76636025056048
# Quantitative_Concept  - -  8.355863929376454
# Body_Space_or_Junction  - -  0.2776579521359005
# Molecular_Function  - -  0.17011865776379026
# Occupation_or_Discipline  - -  0.1506765254479285
# Organization  - -  0.41010747853770857
# Body_Substance  - -  5.180720695542283
# Population_Group  - -  4.147249849627258
# Individual_Behavior  - -  0.2764428188661591
# Group_Attribute  - -  0.04313723107581824
# Cell_Function  - -  0.21993912182318595
# Regulation_or_Law  - -  0.33902218225783914
# Organic_Chemical  - -  2.0632962920208273
# Body_System  - -  0.7527750606047718
# Body_Part_Organ_or_Organ_Component  - -  2.8409815846552973
# Biologically_Active_Substance  - -  0.37790644688956265
# Plant  - -  0.142170592559739
# Idea_or_Concept  - -  10.021811642191858
# Activity  - -  0.7266496953053326
# Self-help_or_Relief_Organization  - -  0.005468099713836115
# Virus  - -  0.12819655995771334
# Professional_Society  - -  0.004252966444094756
# Temporal_Concept  - -  4.44495750071389
# Health_Care_Related_Organization  - -  0.8846170203717092
# Genetic_Function  - -  0.04070696453633552
# Vertebrate  - -  0.0
# Bird  - -  0.04921289742452503
# Finding  - -  21.986013816065277
# Biologic_Function  - -  0.06318693002655067
# Qualitative_Concept  - -  7.849760922529178
# Physical_Object  - -  0.20110455614219488
# Fish  - -  0.02430266539482718
# Indicator_Reagent_or_Diagnostic_Aid  - -  0.24424178721801312
# Substance  - -  0.3949183126659417
# Animal  - -  0.02430266539482718
# Vitamin  - -  0.17315649093814364
# Neoplastic_Process  - -  3.6988656730926968
# Biomedical_or_Dental_Material  - -  0.5692899368738266
# Functional_Concept  - -  12.771658231616554
# Cell  - -  0.25882338645490943
# Sign_or_Symptom  - -  1.8494328365463484
# Behavior  - -  0.08323662897728308
# Experimental_Model_of_Disease  - -  0.0036453998092240763
# Event  - -  0.07898366253318834
# Immunologic_Factor  - -  0.44291607682072526
# Environmental_Effect_of_Humans  - -  0.0012151332697413588
# Daily_or_Recreational_Activity  - -  0.18226999046120385
# Biomedical_Occupation_or_Discipline  - -  1.3202422975739865
# Gene_or_Genome  - -  1.0219270798524829
# Molecular_Biology_Research_Technique  - -  0.013974032602025626
# Acquired_Abnormality  - -  0.09052742859573124
# Phenomenon_or_Process  - -  0.23998882077391837
# Cell_or_Molecular_Dysfunction  - -  0.23755855423443564
# Physiologic_Function  - -  0.2776579521359005
# Research_Device  - -  0.016404299141508344
# Hormone  - -  0.18834565680991064
# Health_Care_Activity  - -  3.259594996081195
# Entity  - -  0.008505932888189512
# Enzyme  - -  0.1980667229678415
# Antibiotic  - -  0.06440206329629201
# Classification  - -  1.753437308236781
# Carbohydrate_Sequence  - -  0.0
# Organ_or_Tissue_Function  - -  0.2484947536621079
# Chemical_Viewed_Structurally  - -  0.030985898378404653
# Natural_Phenomenon_or_Process  - -  0.17558675747762637
# Anatomical_Abnormality  - -  0.17983972392172112
# Intellectual_Product  - -  16.137577388800118
# Amino_Acid_Sequence  - -  0.02551779866456854
# Human  - -  0.3870199464126228
# Chemical  - -  0.018834565680991063
# Mental_or_Behavioral_Dysfunction  - -  2.1204075556986712
# Professional_or_Occupational_Group  - -  0.6245785006470584
# Molecular_Sequence  - -  0.0

# %%
metrics_df_i = getMetrics(semantic_type_labels, labels_gt_i)
# Out:
# Language  - -  0.055573197840584315
# Anatomical_Structure  - -  0.046046363925055574
# Patient_or_Disabled_Group  - -  0.1635439822165767
# Organism_Function  - -  0.5517624642743728
# Body_Location_or_Region  - -  0.6176563988567799
# Archaeon  - -  0.009526833915528738
# Chemical_Viewed_Functionally  - -  0.2683391552873928
# Mammal  - -  0.10717688154969832
# Nucleic_Acid_Nucleoside_or_Nucleotide  - -  0.3493172435693871
# Disease_or_Syndrome  - -  1.13369323594792
# Organism_Attribute  - -  0.16275007939028263
# Spatial_Concept  - -  2.8318513813909174
# Medical_Device  - -  2.5103207367418228
# Element_Ion_or_Isotope  - -  0.747856462369006
# Injury_or_Poisoning  - -  0.4660209590346142
# Inorganic_Chemical  - -  1.0741505239758653
# Food  - -  1.1051127342013336
# Social_Behavior  - -  0.49857097491267066
# Occupational_Activity  - -  0.39933312162591295
# Fully_Formed_Anatomical_Structure  - -  0.034137821530644645
# Laboratory_Procedure  - -  4.693553509050492
# Group  - -  0.7280088917116545
# Clinical_Drug  - -  0.4517307081613211
# Nucleotide_Sequence  - -  0.02461098761511591
# Age_Group  - -  0.0746268656716418
# Amino_Acid_Peptide_or_Protein  - -  2.9557002222927915
# Hazardous_or_Poisonous_Substance  - -  0.3540806605271515
# Tissue  - -  0.2691330581136869
# Manufactured_Object  - -  2.5444585582724675
# Governmental_or_Regulatory_Activity  - -  0.10400127024452208
# Mental_Process  - -  0.8590028580501747
# Congenital_Abnormality  - -  0.007145125436646554
# Pharmacologic_Substance  - -  16.876786281359163
# Educational_Activity  - -  1.5163543982216576
# Human-caused_Phenomenon_or_Process  - -  0.056367100666878375
# Organism  - -  0.22467449984121943
# Laboratory_or_Test_Result  - -  0.3286757700857415
# Clinical_Attribute  - -  2.0752619879326772
# Eukaryote  - -  0.19291838678945697
# Pathologic_Function  - -  0.37234042553191493
# Machine_Activity  - -  0.2913623372499206
# Drug_Delivery_Device  - -  0.004763416957764369
# Research_Activity  - -  2.9183867894569704
# Amphibian  - -  0.0031756113051762463
# Conceptual_Entity  - -  3.025563671006669
# Diagnostic_Procedure  - -  1.714830104795173
# Cell_Component  - -  0.2993013655128612
# Receptor  - -  0.12305493807557955
# Embryonic_Structure  - -  0.02381708478882185
# Fungus  - -  0.01508415369958717
# Reptile  - -  0.0023817084788821845
# Family_Group  - -  0.1762464274372817
# Geographic_Area  - -  0.13734518894887265
# Bacterium  - -  0.0785963798031121
# Therapeutic_or_Preventive_Procedure  - -  12.650047634169578
# Quantitative_Concept  - -  4.015560495395364
# Body_Space_or_Junction  - -  0.48825023817084784
# Molecular_Function  - -  0.7232454747538901
# Occupation_or_Discipline  - -  0.20720863766275008
# Organization  - -  0.31835503334391874
# Body_Substance  - -  1.4790409653858367
# Population_Group  - -  1.1741822800889172
# Individual_Behavior  - -  0.25722451571927596
# Group_Attribute  - -  0.007145125436646554
# Cell_Function  - -  0.055573197840584315
# Regulation_or_Law  - -  0.5366783105747857
# Organic_Chemical  - -  13.337567481740233
# Body_System  - -  0.4501429025087329
# Body_Part_Organ_or_Organ_Component  - -  1.5362019688790092
# Biologically_Active_Substance  - -  2.036360749444268
# Plant  - -  0.49777707208637667
# Idea_or_Concept  - -  4.561765639885678
# Activity  - -  1.3599555414417275
# Self-help_or_Relief_Organization  - -  0.013496348046999047
# Virus  - -  0.046046363925055574
# Professional_Society  - -  0.0023817084788821845
# Temporal_Concept  - -  4.380755795490632
# Health_Care_Related_Organization  - -  0.32311845030168307
# Genetic_Function  - -  0.07303906001905366
# Vertebrate  - -  0.0
# Bird  - -  0.022229279136233727
# Finding  - -  12.536519530009526
# Biologic_Function  - -  0.08494760241346459
# Qualitative_Concept  - -  6.34487138774214
# Physical_Object  - -  0.21752937440457287
# Fish  - -  0.04366465544617339
# Indicator_Reagent_or_Diagnostic_Aid  - -  0.7939028262940616
# Substance  - -  1.1067005398539218
# Animal  - -  0.04366465544617339
# Vitamin  - -  0.6613210543029533
# Neoplastic_Process  - -  0.4040965385836774
# Biomedical_or_Dental_Material  - -  3.3097808828199424
# Functional_Concept  - -  10.618450301683074
# Cell  - -  0.21197205462051444
# Sign_or_Symptom  - -  0.5962210225468403
# Behavior  - -  0.11670371546522705
# Experimental_Model_of_Disease  - -  0.0
# Event  - -  0.10876468720228644
# Immunologic_Factor  - -  1.3805970149253732
# Environmental_Effect_of_Humans  - -  0.0031756113051762463
# Daily_or_Recreational_Activity  - -  0.7970784375992378
# Biomedical_Occupation_or_Discipline  - -  0.9296602095903461
# Gene_or_Genome  - -  1.9164814226738647
# Molecular_Biology_Research_Technique  - -  0.03651953000952683
# Acquired_Abnormality  - -  0.05080978088281994
# Phenomenon_or_Process  - -  0.5208002540489044
# Cell_or_Molecular_Dysfunction  - -  0.04525246109876151
# Physiologic_Function  - -  0.6073356621149572
# Research_Device  - -  0.06033661479834868
# Hormone  - -  1.4266433788504287
# Health_Care_Activity  - -  4.722134010797078
# Entity  - -  0.031756113051762465
# Enzyme  - -  0.5176246427437281
# Antibiotic  - -  0.8621784693553508
# Classification  - -  1.4107653223245475
# Carbohydrate_Sequence  - -  0.0
# Organ_or_Tissue_Function  - -  0.3413782153064465
# Chemical_Viewed_Structurally  - -  0.11432200698634487
# Natural_Phenomenon_or_Process  - -  0.7597650047634169
# Anatomical_Abnormality  - -  0.08018418545570022
# Intellectual_Product  - -  9.660209590346142
# Amino_Acid_Sequence  - -  0.016671959352175296
# Human  - -  0.15163543982216576
# Chemical  - -  0.3151794220387425
# Mental_or_Behavioral_Dysfunction  - -  0.2754842807240394
# Professional_or_Occupational_Group  - -  0.2977135598602731
# Molecular_Sequence  - -  0.0

# %%
metrics_df_o = getMetrics(semantic_type_labels, labels_gt_o)
# Out:
# Language  - -  0.0841242727424513
# Anatomical_Structure  - -  0.13614004443816546
# Patient_or_Disabled_Group  - -  0.2607210284995055
# Organism_Function  - -  2.1474165500057794
# Body_Location_or_Region  - -  0.9915105123232426
# Archaeon  - -  0.0012843400418694854
# Chemical_Viewed_Functionally  - -  0.046878411528236213
# Mammal  - -  0.041098881339823534
# Nucleic_Acid_Nucleoside_or_Nucleotide  - -  0.08990380293086397
# Disease_or_Syndrome  - -  4.957552561616214
# Organism_Attribute  - -  1.4410295269775626
# Spatial_Concept  - -  3.510743504450238
# Medical_Device  - -  1.467358497835887
# Element_Ion_or_Isotope  - -  0.2780596190647436
# Injury_or_Poisoning  - -  0.701249662860739
# Inorganic_Chemical  - -  0.28191263919035203
# Food  - -  0.38530201256084556
# Social_Behavior  - -  0.9870153221766995
# Occupational_Activity  - -  0.391723712770193
# Fully_Formed_Anatomical_Structure  - -  0.1367822144591002
# Laboratory_Procedure  - -  4.8926933895018045
# Group  - -  0.19008232619668383
# Clinical_Drug  - -  0.03210850104673714
# Nucleotide_Sequence  - -  0.014127740460564338
# Age_Group  - -  0.17338590565238052
# Amino_Acid_Peptide_or_Protein  - -  1.9361426131182493
# Hazardous_or_Poisonous_Substance  - -  0.2465932880389412
# Tissue  - -  0.6261157704113741
# Manufactured_Object  - -  1.9342161030554448
# Governmental_or_Regulatory_Activity  - -  0.20934742682472612
# Mental_Process  - -  4.042460281784206
# Congenital_Abnormality  - -  0.055868791821322615
# Pharmacologic_Substance  - -  5.474499428468682
# Educational_Activity  - -  0.23824507776678952
# Human-caused_Phenomenon_or_Process  - -  0.34163445113728313
# Organism  - -  0.2812704691694173
# Laboratory_or_Test_Result  - -  1.3697486546538062
# Clinical_Attribute  - -  7.254594726499788
# Eukaryote  - -  0.38787069264458457
# Pathologic_Function  - -  3.775959723096287
# Machine_Activity  - -  0.12201230397760111
# Drug_Delivery_Device  - -  0.0012843400418694854
# Research_Activity  - -  1.7107409357701546
# Amphibian  - -  0.004495190146543199
# Conceptual_Entity  - -  2.707388808260875
# Diagnostic_Procedure  - -  2.9533399262788818
# Cell_Component  - -  0.6023554796367886
# Receptor  - -  0.11237975366357998
# Embryonic_Structure  - -  0.048162751570105695
# Fungus  - -  0.021191610690846508
# Reptile  - -  0.0012843400418694854
# Family_Group  - -  0.4546563748217978
# Geographic_Area  - -  0.8772042485968585
# Bacterium  - -  0.08476644276338603
# Therapeutic_or_Preventive_Procedure  - -  4.033469901491118
# Quantitative_Concept  - -  12.00472637135408
# Body_Space_or_Junction  - -  0.326864540655784
# Molecular_Function  - -  1.0261876934537189
# Occupation_or_Discipline  - -  0.1714593955895763
# Organization  - -  0.1008206932867546
# Body_Substance  - -  2.7433503294332207
# Population_Group  - -  0.5882277391762243
# Individual_Behavior  - -  0.9048175594970524
# Group_Attribute  - -  0.017980760586172796
# Cell_Function  - -  0.41034664337730054
# Regulation_or_Law  - -  0.546486687815466
# Organic_Chemical  - -  3.932649208204364
# Body_System  - -  1.562399660934229
# Body_Part_Organ_or_Organ_Component  - -  3.714953571107486
# Biologically_Active_Substance  - -  1.8565135305223412
# Plant  - -  0.15155212494059928
# Idea_or_Concept  - -  7.459446963177971
# Activity  - -  3.603215987464841
# Self-help_or_Relief_Organization  - -  0.006421700209347426
# Virus  - -  0.055226621800387864
# Professional_Society  - -  0.0
# Temporal_Concept  - -  5.188091599131786
# Health_Care_Related_Organization  - -  0.3962189029167363
# Genetic_Function  - -  0.20549440669911764
# Vertebrate  - -  0.0
# Bird  - -  0.022475950732715994
# Finding  - -  25.403603858157485
# Biologic_Function  - -  0.31081029013241546
# Qualitative_Concept  - -  12.24425578916274
# Physical_Object  - -  0.04880492159104044
# Fish  - -  0.010916890355890625
# Indicator_Reagent_or_Diagnostic_Aid  - -  0.7937221458753421
# Substance  - -  0.33585492094887043
# Animal  - -  0.03082416100486765
# Vitamin  - -  0.3820911624561719
# Neoplastic_Process  - -  1.5970768420647052
# Biomedical_or_Dental_Material  - -  0.6151988800554835
# Functional_Concept  - -  12.207009927948524
# Cell  - -  0.591438589280898
# Sign_or_Symptom  - -  3.9621890291673623
# Behavior  - -  0.41419966350290904
# Experimental_Model_of_Disease  - -  0.0
# Event  - -  0.32108501046737137
# Immunologic_Factor  - -  0.8149137565661885
# Environmental_Effect_of_Humans  - -  0.0
# Daily_or_Recreational_Activity  - -  0.74877024440991
# Biomedical_Occupation_or_Discipline  - -  0.43025391402627755
# Gene_or_Genome  - -  1.5938659919600313
# Molecular_Biology_Research_Technique  - -  0.020549440669911767
# Acquired_Abnormality  - -  0.11559060376825367
# Phenomenon_or_Process  - -  1.1250818766776691
# Cell_or_Molecular_Dysfunction  - -  0.28961867944156894
# Physiologic_Function  - -  1.9631137539975085
# Research_Device  - -  0.019907270648977023
# Hormone  - -  0.5663939584644431
# Health_Care_Activity  - -  4.283916209655668
# Entity  - -  0.14256174464751287
# Enzyme  - -  0.5574035781713567
# Antibiotic  - -  0.06100615198880056
# Classification  - -  1.6741372445768743
# Carbohydrate_Sequence  - -  0.0
# Organ_or_Tissue_Function  - -  1.762114537444934
# Chemical_Viewed_Structurally  - -  0.10724239349610204
# Natural_Phenomenon_or_Process  - -  0.7815209154775818
# Anatomical_Abnormality  - -  0.13870872452190441
# Intellectual_Product  - -  20.427428365934162
# Amino_Acid_Sequence  - -  0.03531935115141085
# Human  - -  0.1958618563850965
# Chemical  - -  0.09311465303553769
# Mental_or_Behavioral_Dysfunction  - -  1.3280076032930477
# Professional_or_Occupational_Group  - -  0.15733165512901195
# Molecular_Sequence  - -  0.0

# %%
metrics_df_s = getMetrics(semantic_type_labels, labels_gt_s)
# Out:
# Language  - -  0.0
# Anatomical_Structure  - -  0.0
# Patient_or_Disabled_Group  - -  4.537634408602151
# Organism_Function  - -  0.06451612903225806
# Body_Location_or_Region  - -  0.0
# Archaeon  - -  0.0
# Chemical_Viewed_Functionally  - -  0.0
# Mammal  - -  0.0
# Nucleic_Acid_Nucleoside_or_Nucleotide  - -  0.0
# Disease_or_Syndrome  - -  4.602150537634408
# Organism_Attribute  - -  0.0
# Spatial_Concept  - -  1.3548387096774193
# Medical_Device  - -  0.0
# Element_Ion_or_Isotope  - -  0.0
# Injury_or_Poisoning  - -  0.0
# Inorganic_Chemical  - -  0.021505376344086023
# Food  - -  0.0
# Social_Behavior  - -  0.27956989247311825
# Occupational_Activity  - -  0.043010752688172046
# Fully_Formed_Anatomical_Structure  - -  0.0
# Laboratory_Procedure  - -  0.27956989247311825
# Group  - -  4.881720430107527
# Clinical_Drug  - -  0.0
# Nucleotide_Sequence  - -  0.0
# Age_Group  - -  0.0
# Amino_Acid_Peptide_or_Protein  - -  0.021505376344086023
# Hazardous_or_Poisonous_Substance  - -  0.0
# Tissue  - -  0.0
# Manufactured_Object  - -  0.967741935483871
# Governmental_or_Regulatory_Activity  - -  0.043010752688172046
# Mental_Process  - -  0.0
# Congenital_Abnormality  - -  0.0
# Pharmacologic_Substance  - -  0.21505376344086022
# Educational_Activity  - -  0.0
# Human-caused_Phenomenon_or_Process  - -  0.0
# Organism  - -  0.0
# Laboratory_or_Test_Result  - -  0.0
# Clinical_Attribute  - -  0.12903225806451613
# Eukaryote  - -  0.021505376344086023
# Pathologic_Function  - -  0.06451612903225806
# Machine_Activity  - -  0.0
# Drug_Delivery_Device  - -  0.0
# Research_Activity  - -  30.946236559139784
# Amphibian  - -  0.0
# Conceptual_Entity  - -  4.559139784946237
# Diagnostic_Procedure  - -  0.0
# Cell_Component  - -  0.0
# Receptor  - -  0.0
# Embryonic_Structure  - -  0.0
# Fungus  - -  0.0
# Reptile  - -  0.0
# Family_Group  - -  0.0
# Geographic_Area  - -  0.0
# Bacterium  - -  0.0
# Therapeutic_or_Preventive_Procedure  - -  10.989247311827958
# Quantitative_Concept  - -  1.118279569892473
# Body_Space_or_Junction  - -  0.0
# Molecular_Function  - -  0.0
# Occupation_or_Discipline  - -  0.23655913978494625
# Organization  - -  0.021505376344086023
# Body_Substance  - -  0.08602150537634409
# Population_Group  - -  4.236559139784946
# Individual_Behavior  - -  0.0
# Group_Attribute  - -  0.0
# Cell_Function  - -  1.053763440860215
# Regulation_or_Law  - -  4.279569892473118
# Organic_Chemical  - -  0.12903225806451613
# Body_System  - -  0.0
# Body_Part_Organ_or_Organ_Component  - -  0.0
# Biologically_Active_Substance  - -  0.0
# Plant  - -  0.0
# Idea_or_Concept  - -  7.849462365591398
# Activity  - -  0.17204301075268819
# Self-help_or_Relief_Organization  - -  0.0
# Virus  - -  0.0
# Professional_Society  - -  0.0
# Temporal_Concept  - -  1.3548387096774193
# Health_Care_Related_Organization  - -  0.0
# Genetic_Function  - -  0.3010752688172043
# Vertebrate  - -  0.0
# Bird  - -  0.0
# Finding  - -  2.021505376344086
# Biologic_Function  - -  0.0
# Qualitative_Concept  - -  17.591397849462364
# Physical_Object  - -  0.0
# Fish  - -  0.0
# Indicator_Reagent_or_Diagnostic_Aid  - -  0.0
# Substance  - -  0.23655913978494625
# Animal  - -  0.0
# Vitamin  - -  0.0
# Neoplastic_Process  - -  0.0
# Biomedical_or_Dental_Material  - -  10.774193548387096
# Functional_Concept  - -  11.935483870967742
# Cell  - -  0.0
# Sign_or_Symptom  - -  0.0
# Behavior  - -  0.0
# Experimental_Model_of_Disease  - -  0.0
# Event  - -  0.0
# Immunologic_Factor  - -  0.021505376344086023
# Environmental_Effect_of_Humans  - -  0.0
# Daily_or_Recreational_Activity  - -  0.0
# Biomedical_Occupation_or_Discipline  - -  0.0
# Gene_or_Genome  - -  0.0
# Molecular_Biology_Research_Technique  - -  0.0
# Acquired_Abnormality  - -  0.0
# Phenomenon_or_Process  - -  0.0
# Cell_or_Molecular_Dysfunction  - -  0.0
# Physiologic_Function  - -  0.0
# Research_Device  - -  0.0
# Hormone  - -  0.0
# Health_Care_Activity  - -  0.40860215053763443
# Entity  - -  0.0
# Enzyme  - -  0.0
# Antibiotic  - -  0.0
# Classification  - -  5.118279569892473
# Carbohydrate_Sequence  - -  0.0
# Organ_or_Tissue_Function  - -  0.0
# Chemical_Viewed_Structurally  - -  0.0
# Natural_Phenomenon_or_Process  - -  0.0
# Anatomical_Abnormality  - -  0.0
# Intellectual_Product  - -  15.354838709677418
# Amino_Acid_Sequence  - -  0.0
# Human  - -  0.0
# Chemical  - -  0.0
# Mental_or_Behavioral_Dysfunction  - -  0.0
# Professional_or_Occupational_Group  - -  0.5806451612903226
# Molecular_Sequence  - -  0.0

# %%
metrics_df_p_sorted = metrics_df_p.sort_values(by=['R'], ascending=False, inplace=False)

# %%
metrics_df_i_sorted = metrics_df_i.sort_values(by=['R'], ascending=False, inplace=False)

# %%
metrics_df_o_sorted = metrics_df_o.sort_values(by=['R'], ascending=False, inplace=False)

# %%
metrics_df_s_sorted = metrics_df_s.sort_values(by=['R'], ascending=False, inplace=False)

# %%
def writeMetrics(picos, df, filename):

    writedir = '/mnt/nas2/results/Results/systematicReview/distant_pico/semantic_to_target'
    if reverse == True:
        filename = f'{filename}_{picos}' + '.tsv'
    else: 
        filename = f'{filename}_{picos}' + '.tsv'
    df.to_csv(f'{writedir}/{filename}', sep='\t')

    
#writeMetrics('p', metrics_df_p_sorted, 'sty_metrics')
#writeMetrics('i', metrics_df_i_sorted, 'sty_metrics')
#writeMetrics('o', metrics_df_o_sorted, 'sty_metrics')
writeMetrics('s', metrics_df_s_sorted, 'sty_metrics')

# %%
# Measure gains to the best recall by addition of more semantic groups. This will increase the "seen" entity for the label model

# %%
metrics_df_o_sorted
# Out:
#                                STY         f1          R
# 81                         Finding  21.636211  25.403604
# 120           Intellectual_Product  19.879014  20.427428
# 83             Qualitative_Concept  13.950256  12.244256
# 92              Functional_Concept  13.105904  12.207010
# 55            Quantitative_Concept  15.012789  12.004726
# ..                             ...        ...        ...
# 115          Carbohydrate_Sequence   0.000000   0.000000
# 96   Experimental_Model_of_Disease   0.000000   0.000000
# 79                      Vertebrate   0.000000   0.000000
# 75            Professional_Society   0.000000   0.000000
# 126             Molecular_Sequence   0.000000   0.000000
#
# [127 rows x 3 columns]

# %%
metrics_df_i_sorted
# Out:
#                                      STY         f1          R
# 32               Pharmacologic_Substance  23.947819  16.876786
# 66                      Organic_Chemical  20.487305  13.337567
# 54   Therapeutic_or_Preventive_Procedure  17.467852  12.650048
# 81                               Finding   9.401867  12.536520
# 92                    Functional_Concept  10.275775  10.618450
# ..                                   ...        ...        ...
# 50                               Reptile   0.004762   0.002382
# 115                Carbohydrate_Sequence   0.000000   0.000000
# 96         Experimental_Model_of_Disease   0.000000   0.000000
# 79                            Vertebrate   0.000000   0.000000
# 126                   Molecular_Sequence   0.000000   0.000000
#
# [127 rows x 3 columns]

# %%
metrics_df_p_sorted
# Out:
#                                 STY         f1          R
# 81                          Finding  19.323282  21.986014
# 120            Intellectual_Product  16.151168  16.137577
# 92               Functional_Concept  14.063127  12.771658
# 71                  Idea_or_Concept  12.750300  10.021812
# 55             Quantitative_Concept  10.664961   8.355864
# ..                              ...        ...        ...
# 99   Environmental_Effect_of_Humans   0.002430   0.001215
# 41             Drug_Delivery_Device   0.002430   0.001215
# 115           Carbohydrate_Sequence   0.000000   0.000000
# 79                       Vertebrate   0.000000   0.000000
# 126              Molecular_Sequence   0.000000   0.000000
#
# [127 rows x 3 columns]

# %%
metrics_df_s_sorted
# Out:
#                                      STY         f1          R
# 42                     Research_Activity  36.648415  30.946237
# 83                   Qualitative_Concept   9.806978  17.591398
# 120                 Intellectual_Product   6.889232  15.354839
# 92                    Functional_Concept   5.676588  11.935484
# 54   Therapeutic_or_Preventive_Procedure   8.761252  10.989247
# ..                                   ...        ...        ...
# 47                              Receptor   0.000000   0.000000
# 46                        Cell_Component   0.000000   0.000000
# 45                  Diagnostic_Procedure   0.000000   0.000000
# 43                             Amphibian   0.000000   0.000000
# 126                   Molecular_Sequence   0.000000   0.000000
#
# [127 rows x 3 columns]

# %%
merged_score_p_r = dict()
merged_score_p_f1 = dict()

merged_p = [0] * len(labels_gt_p)

for i in list(metrics_df_p_sorted.STY):
    
    lf_labs = list(semantic_type_labels[i])
    gt = labels_gt_p
    
    for counter, (o,n) in enumerate( zip(merged_p, lf_labs) ):
        
        if (o + n) >= 1:
            merged_p[counter] = 1

    recall_updated = recall_score(gt, merged_p, average='binary',pos_label=1)
    recall_updated = recall_updated * 100   
    merged_score_p_r[i] = recall_updated
    print( i ,  recall_updated )
    
    f1_updated = f1_score(gt, merged_p, average='binary',pos_label=1)
    f1_updated = f1_updated * 100
    merged_score_p_f1[i] = f1_updated
    #print( '\t\t\t\t' ,  f1_updated )
# Out:
# Finding 21.986013816065277
# Intellectual_Product 26.817383696556917
# Functional_Concept 28.923209653018695
# Idea_or_Concept 29.997995030104928
# Quantitative_Concept 32.1287312185964
# Clinical_Attribute 32.67493362334514
# Qualitative_Concept 35.361593282743286
# Disease_or_Syndrome 37.16181322186511
# Body_Substance 37.266922249697735
# Therapeutic_or_Preventive_Procedure 38.39578105728746
# Patient_or_Disabled_Group 38.50089008512009
# Temporal_Concept 39.186225249254214
# Population_Group 40.6784089044966
# Organism 40.68448457084531
# Neoplastic_Process 41.216712942992025
# Health_Care_Activity 41.36981973497944
# Conceptual_Entity 41.442120164529044
# Pharmacologic_Substance 42.38081061540424
# Body_Part_Organ_or_Organ_Component 42.77512136143532
# Spatial_Concept 43.2769714018385
# Mental_or_Behavioral_Dysfunction 43.5856152523528
# Manufactured_Object 43.76120200983043
# Organic_Chemical 43.91673906835732
# Research_Activity 44.03156916234788
# Age_Group 44.07592152669344
# Sign_or_Symptom 44.195004587128096
# Classification 44.243002351282875
# Family_Group 44.30497414803969
# Biomedical_Occupation_or_Discipline 44.35661731200369
# Diagnostic_Procedure 44.453827973583
# Body_Location_or_Region 44.48845927177063
# Pathologic_Function 44.57169590074791
# Gene_or_Genome 44.63731309731395
# Laboratory_Procedure 44.69199409445231
# Medical_Device 44.73634645879787
# Group 44.780091256508555
# Health_Care_Related_Organization 44.80864688834748
# Educational_Activity 44.81958308777515
# Eukaryote 44.857859785772
# Organism_Attribute 44.887022984245796
# Mental_Process 44.961753680334894
# Body_System 44.96843691331846
# Activity 45.134910171273035
# Geographic_Area 45.5292209173041
# Amino_Acid_Peptide_or_Protein 45.554738715968675
# Professional_or_Occupational_Group 45.63189967859725
# Biomedical_or_Dental_Material 45.653164510817724
# Laboratory_or_Test_Result 45.66531584351514
# Organism_Function 45.69690930852841
# Injury_or_Poisoning 45.7199968406535
# Immunologic_Factor 45.73579357316014
# Organization 45.75705840538061
# Substance 45.76495677163393
# Tissue 45.769817304712895
# Human 45.857914466769145
# Biologically_Active_Substance 45.868243099561944
# Regulation_or_Law 45.86885066619681
# Social_Behavior 45.924139229970045
# Mammal 46.03775419069087
# Body_Space_or_Junction 46.042007157134954
# Physiologic_Function 46.050513090023145
# Individual_Behavior 46.06509468926004
# Cell_Component 46.06570225589491
# Cell 46.07967628849694
# Organ_or_Tissue_Function 46.08514438821077
# Indicator_Reagent_or_Diagnostic_Aid 46.09000492128974
# Phenomenon_or_Process 46.106409220431246
# Cell_or_Molecular_Dysfunction 46.110662186875345
# Occupational_Activity 46.133749719000434
# Cell_Function 46.13617998553992
# Food 46.152584284681424
# Physical_Object 46.152584284681424
# Enzyme 46.152584284681424
# Hormone 46.152584284681424
# Daily_or_Recreational_Activity 46.16595075064858
# Anatomical_Abnormality 46.17445668353677
# Natural_Phenomenon_or_Process 46.190253416043404
# Vitamin 46.190253416043404
# Molecular_Function 46.194506382487496
# Occupation_or_Discipline 46.204835015280295
# Language 46.21151824826388
# Plant 46.21455608143823
# Virus 46.218809047882324
# Inorganic_Chemical 46.22306201432642
# Governmental_or_Regulatory_Activity 46.22366958096129
# Hazardous_or_Poisonous_Substance 46.22488471423104
# Machine_Activity 46.22549228086591
# Acquired_Abnormality 46.228530114040254
# Receptor 46.228530114040254
# Behavior 46.236428480293576
# Congenital_Abnormality 46.2400738801028
# Event 46.241289013372544
# Anatomical_Structure 46.24311171327715
# Bacterium 46.25222521280021
# Antibiotic 46.25222521280021
# Biologic_Function 46.25404791270483
# Fully_Formed_Anatomical_Structure 46.25404791270483
# Chemical_Viewed_Functionally 46.25404791270483
# Element_Ion_or_Isotope 46.2546554793397
# Bird 46.27470517829043
# Nucleic_Acid_Nucleoside_or_Nucleotide 46.278958144734524
# Human-caused_Phenomenon_or_Process 46.28017327800427
# Group_Attribute 46.28138841127401
# Genetic_Function 46.28260354454375
# Nucleotide_Sequence 46.28260354454375
# Clinical_Drug 46.28260354454375
# Chemical_Viewed_Structurally 46.283211111178616
# Amino_Acid_Sequence 46.283211111178616
# Animal 46.283211111178616
# Fish 46.2856413777181
# Embryonic_Structure 46.29110947743194
# Chemical 46.29171704406681
# Research_Device 46.29171704406681
# Molecular_Biology_Research_Technique 46.29171704406681
# Fungus 46.292932177336546
# Entity 46.292932177336546
# Archaeon 46.296577577145776
# Amphibian 46.296577577145776
# Self-help_or_Relief_Organization 46.297185143780645
# Reptile 46.300222976955
# Professional_Society 46.30083054358987
# Experimental_Model_of_Disease 46.30083054358987
# Environmental_Effect_of_Humans 46.30083054358987
# Drug_Delivery_Device 46.30083054358987
# Carbohydrate_Sequence 46.30083054358987
# Vertebrate 46.30083054358987
# Molecular_Sequence 46.30083054358987

# %%
merged_score_i_r = dict()
merged_score_i_f1 = dict()

merged_i = [0] * len(labels_gt_i)

for i in list(metrics_df_i_sorted.STY):
    
    lf_labs = list(semantic_type_labels[i])
    gt = labels_gt_i
    
    for counter, (o,n) in enumerate( zip(merged_i, lf_labs) ):
        
        if (o + n) >= 1:
            merged_i[counter] = 1

    recall_updated = recall_score(gt, merged_i, average='binary',pos_label=1)
    recall_updated = recall_updated * 100   
    print( i ,  recall_updated )
    merged_score_i_r[i] = recall_updated
    
    f1_updated = f1_score(gt, merged_i, average='binary',pos_label=1)
    f1_updated = f1_updated * 100
    merged_score_i_f1[i] = f1_updated
    #print( '\t\t\t\t' ,  f1_updated )
# Out:
# Pharmacologic_Substance 16.876786281359163
# Organic_Chemical 18.159733248650365
# Therapeutic_or_Preventive_Procedure 29.509368053350272
# Finding 35.963798031120994
# Functional_Concept 39.085423944109245
# Intellectual_Product 41.64734836456018
# Qualitative_Concept 43.12956494125119
# Health_Care_Activity 43.59241028898062
# Laboratory_Procedure 43.967132422991426
# Idea_or_Concept 44.53318513813909
# Temporal_Concept 45.07780247697682
# Quantitative_Concept 45.784375992378536
# Biomedical_or_Dental_Material 46.076532232454745
# Conceptual_Entity 46.18450301683074
# Amino_Acid_Peptide_or_Protein 46.36233724992061
# Research_Activity 46.46157510320737
# Spatial_Concept 47.16656081295649
# Manufactured_Object 47.62623054938076
# Medical_Device 48.017624642743726
# Clinical_Attribute 48.12003810733566
# Biologically_Active_Substance 48.214512543664654
# Gene_or_Genome 48.28040647824706
# Diagnostic_Procedure 48.52016513178787
# Body_Part_Organ_or_Organ_Component 48.75516036837091
# Educational_Activity 48.79247380120673
# Body_Substance 48.83137503969514
# Hormone 48.83137503969514
# Classification 48.84804699904732
# Immunologic_Factor 48.85757383296285
# Activity 49.07510320736742
# Population_Group 49.19021911718006
# Disease_or_Syndrome 49.26167037154652
# Substance 49.39980946332169
# Food 49.56097173705938
# Inorganic_Chemical 49.598285169895206
# Biomedical_Occupation_or_Discipline 49.61892664337885
# Antibiotic 49.62210225468402
# Mental_Process 49.785646236900604
# Daily_or_Recreational_Activity 49.81660844712607
# Indicator_Reagent_or_Diagnostic_Aid 49.840425531914896
# Natural_Phenomenon_or_Process 49.92616703715465
# Element_Ion_or_Isotope 49.93569387107018
# Group 49.95792315020641
# Molecular_Function 49.97538901238489
# Vitamin 49.97538901238489
# Body_Location_or_Region 50.02540489044141
# Physiologic_Function 50.03493172435694
# Sign_or_Symptom 50.05874880914576
# Organism_Function 50.09050492219752
# Regulation_or_Law 50.09765004763417
# Phenomenon_or_Process 50.1468720228644
# Enzyme 50.1468720228644
# Social_Behavior 50.252461098761515
# Plant 50.302476976818035
# Body_Space_or_Junction 50.31835503334392
# Injury_or_Poisoning 50.323118450301685
# Clinical_Drug 50.34137821530644
# Body_System 50.36201968879009
# Neoplastic_Process 50.375516036837084
# Occupational_Activity 50.44776119402985
# Pathologic_Function 50.471578278818676
# Hazardous_or_Poisonous_Substance 50.471578278818676
# Nucleic_Acid_Nucleoside_or_Nucleotide 50.48269291838678
# Organ_or_Tissue_Function 50.49777707208638
# Laboratory_or_Test_Result 50.49936487773896
# Health_Care_Related_Organization 50.516036837091136
# Organization 50.5208002540489
# Chemical 50.52476976818038
# Cell_Component 50.52953318513814
# Professional_or_Occupational_Group 50.58907589711019
# Machine_Activity 50.592251508415366
# Mental_or_Behavioral_Dysfunction 50.613686884725304
# Tissue 50.624007621467136
# Chemical_Viewed_Functionally 50.62718323277231
# Individual_Behavior 50.660527151476664
# Organism 50.71451254366466
# Physical_Object 50.71451254366466
# Cell 50.75738329628453
# Occupation_or_Discipline 50.773261352810415
# Eukaryote 50.79390282629406
# Family_Group 50.811368688472534
# Patient_or_Disabled_Group 50.81216259129883
# Organism_Attribute 50.82010161956176
# Human 50.872499206097174
# Geographic_Area 50.89790409653858
# Receptor 50.89790409653858
# Behavior 50.920133375674816
# Chemical_Viewed_Structurally 50.92807240393776
# Event 50.932041918069224
# Mammal 50.95109558590028
# Governmental_or_Regulatory_Activity 50.95903461416322
# Biologic_Function 50.96697364242617
# Anatomical_Abnormality 50.97094315655764
# Bacterium 51.01063829787233
# Age_Group 51.01302000635122
# Genetic_Function 51.0154017148301
# Research_Device 51.017783423308984
# Human-caused_Phenomenon_or_Process 51.02492854874563
# Language 51.027310257224514
# Cell_Function 51.03207367418228
# Acquired_Abnormality 51.03286757700858
# Virus 51.03524928548746
# Anatomical_Structure 51.03921879961892
# Cell_or_Molecular_Dysfunction 51.03921879961892
# Animal 51.03921879961892
# Fish 51.04080660527151
# Molecular_Biology_Research_Technique 51.04239441092411
# Fully_Formed_Anatomical_Structure 51.04239441092411
# Entity 51.04239441092411
# Nucleotide_Sequence 51.0431883137504
# Embryonic_Structure 51.04477611940299
# Bird 51.04636392505557
# Amino_Acid_Sequence 51.04636392505557
# Fungus 51.05350905049222
# Self-help_or_Relief_Organization 51.05350905049222
# Archaeon 51.05827246744998
# Group_Attribute 51.05906637027628
# Congenital_Abnormality 51.05906637027628
# Drug_Delivery_Device 51.05906637027628
# Environmental_Effect_of_Humans 51.06065417592887
# Amphibian 51.063035884407746
# Professional_Society 51.063035884407746
# Reptile 51.06462369006034
# Carbohydrate_Sequence 51.06462369006034
# Experimental_Model_of_Disease 51.06462369006034
# Vertebrate 51.06462369006034
# Molecular_Sequence 51.06462369006034

# %%
merged_score_o_r = dict()
merged_score_o_f1 = dict()

merged_o = [0] * len(labels_gt_o)

for i in list(metrics_df_o_sorted.STY):
    
    lf_labs = list(semantic_type_labels[i])
    gt = labels_gt_o
    
    for counter, (o,n) in enumerate( zip(merged_o, lf_labs) ):
        
        if (o + n) >= 1:
            merged_o[counter] = 1

    recall_updated = recall_score(gt, merged_o, average='binary',pos_label=1)
    recall_updated = recall_updated * 100   
    print( i ,  recall_updated )
    merged_score_o_r[i] = recall_updated
    
    f1_updated = f1_score(gt, merged_o, average='binary',pos_label=1)
    f1_updated = f1_updated * 100
    merged_score_o_f1[i] = f1_updated
    #print( '\t\t\t\t' ,  f1_updated )
# Out:
# Finding 25.403603858157485
# Intellectual_Product 34.31435506864797
# Qualitative_Concept 38.22645483618243
# Functional_Concept 42.08846534208397
# Quantitative_Concept 44.82924699143345
# Idea_or_Concept 45.83552741423819
# Clinical_Attribute 46.714016002876924
# Pharmacologic_Substance 48.61355492480189
# Temporal_Concept 49.57552561616214
# Disease_or_Syndrome 50.474563645470774
# Laboratory_Procedure 51.34213534375361
# Health_Care_Activity 51.61505760265088
# Mental_Process 52.10760200870782
# Therapeutic_or_Preventive_Procedure 52.62454887556029
# Sign_or_Symptom 52.87178433362016
# Organic_Chemical 53.04517023927255
# Pathologic_Function 53.28534182710214
# Body_Part_Organ_or_Organ_Component 54.04567113188888
# Activity 54.42455144424038
# Spatial_Concept 55.00314663310258
# Diagnostic_Procedure 55.21955793015759
# Body_Substance 55.36276184482604
# Conceptual_Entity 55.48284763874083
# Organism_Function 55.61641900309526
# Physiologic_Function 55.66907694481191
# Amino_Acid_Peptide_or_Protein 55.87264484144823
# Manufactured_Object 55.984382425090864
# Biologically_Active_Substance 56.00300535569798
# Organ_or_Tissue_Function 56.10125736890099
# Research_Activity 56.2399660934229
# Classification 56.27079025442776
# Neoplastic_Process 56.35555669719115
# Gene_or_Genome 56.40179293869845
# Body_System 56.42747973953583
# Medical_Device 56.46793645085473
# Organism_Attribute 56.5154570324039
# Laboratory_or_Test_Result 56.5283004328226
# Mental_or_Behavioral_Dysfunction 56.641322356507104
# Phenomenon_or_Process 56.72095143910302
# Molecular_Function 56.76911419067312
# Body_Location_or_Region 56.82819383259912
# Social_Behavior 56.990020677874675
# Individual_Behavior 57.10817996172667
# Geographic_Area 57.135793272626856
# Immunologic_Factor 57.140288462773405
# Indicator_Reagent_or_Diagnostic_Aid 57.14478365291995
# Natural_Phenomenon_or_Process 57.203221124825006
# Daily_or_Recreational_Activity 57.23789830595548
# Injury_or_Poisoning 57.29505143781868
# Tissue 57.36055277995402
# Biomedical_or_Dental_Material 57.372111840330845
# Cell_Component 57.38945043089608
# Cell 57.51082056485275
# Population_Group 57.60329304786735
# Hormone 57.60393521788829
# Enzyme 57.60393521788829
# Regulation_or_Law 57.60457738790923
# Family_Group 57.632832868830356
# Biomedical_Occupation_or_Discipline 57.64888711935372
# Behavior 57.71117761138439
# Cell_Function 57.72145233171935
# Health_Care_Related_Organization 57.73044271201243
# Occupational_Activity 57.76768857322665
# Eukaryote 57.795301884126836
# Food 57.82612604513171
# Vitamin 57.82612604513171
# Human-caused_Phenomenon_or_Process 57.82869472521545
# Substance 57.83961161557134
# Body_Space_or_Junction 57.85309718601097
# Event 57.85438152605283
# Biologic_Function 57.86016105624125
# Cell_or_Molecular_Dysfunction 57.86786709649247
# Inorganic_Chemical 57.87814181682742
# Organism 57.89034304722518
# Element_Ion_or_Isotope 57.89548040739266
# Patient_or_Disabled_Group 57.89933342751827
# Hazardous_or_Poisonous_Substance 57.900617767560135
# Educational_Activity 57.90832380781136
# Governmental_or_Regulatory_Activity 57.91025031787416
# Genetic_Function 57.92180937825099
# Human 57.93401060864875
# Group 57.93850579879529
# Age_Group 57.94107447887903
# Occupation_or_Discipline 57.966761279716415
# Professional_or_Occupational_Group 57.98153119019792
# Plant 57.98731072038633
# Entity 57.98731072038633
# Anatomical_Abnormality 57.99822761074223
# Fully_Formed_Anatomical_Structure 58.00079629082596
# Anatomical_Structure 58.00657582101437
# Machine_Activity 58.00721799103531
# Acquired_Abnormality 58.01299752122372
# Receptor 58.01299752122372
# Chemical_Viewed_Structurally 58.01685054134933
# Organization 58.02840960172615
# Chemical 58.02840960172615
# Nucleic_Acid_Nucleoside_or_Nucleotide 58.033546961893634
# Bacterium 58.048316872375125
# Language 58.050885552458865
# Antibiotic 58.051527722479804
# Congenital_Abnormality 58.05345423254261
# Virus 58.05602291262635
# Physical_Object 58.05602291262635
# Embryonic_Structure 58.06565546294037
# Chemical_Viewed_Functionally 58.06629763296131
# Mammal 58.07528801325439
# Amino_Acid_Sequence 58.07528801325439
# Clinical_Drug 58.07528801325439
# Animal 58.07528801325439
# Bird 58.076572353296264
# Fungus 58.07721452331719
# Molecular_Biology_Research_Technique 58.07785669333813
# Research_Device 58.07785669333813
# Group_Attribute 58.07785669333813
# Nucleotide_Sequence 58.07785669333813
# Fish 58.07785669333813
# Self-help_or_Relief_Organization 58.078498863359066
# Amphibian 58.078498863359066
# Reptile 58.078498863359066
# Drug_Delivery_Device 58.078498863359066
# Archaeon 58.07914103338
# Environmental_Effect_of_Humans 58.07914103338
# Carbohydrate_Sequence 58.07914103338
# Experimental_Model_of_Disease 58.07914103338
# Vertebrate 58.07914103338
# Professional_Society 58.07914103338
# Molecular_Sequence 58.07914103338

# %%
merged_score_s_r = dict()
merged_score_s_f1 = dict()

merged_s = [0] * len(labels_gt_s)

for i in list(metrics_df_s_sorted.STY):
    
    lf_labs = list(semantic_type_labels[i])
    gt = labels_gt_s
    
    for counter, (o,n) in enumerate( zip(merged_s, lf_labs) ):
        
        if (o + n) >= 1:
            merged_s[counter] = 1

    recall_updated = recall_score(gt, merged_s, average='binary',pos_label=1)
    recall_updated = recall_updated * 100   
    merged_score_s_r[i] = recall_updated
    print( i ,  recall_updated )
    
    f1_updated = f1_score(gt, merged_s, average='binary',pos_label=1)
    f1_updated = f1_updated * 100
    merged_score_s_f1[i] = f1_updated
    #print( '\t\t\t\t' ,  f1_updated )
# Out:
# Research_Activity 30.946236559139784
# Qualitative_Concept 40.58064516129033
# Intellectual_Product 49.01075268817204
# Functional_Concept 54.236559139784944
# Therapeutic_or_Preventive_Procedure 64.9247311827957
# Biomedical_or_Dental_Material 64.9247311827957
# Idea_or_Concept 64.98924731182795
# Classification 65.46236559139786
# Group 65.46236559139786
# Disease_or_Syndrome 69.3763440860215
# Conceptual_Entity 69.44086021505377
# Patient_or_Disabled_Group 69.44086021505377
# Regulation_or_Law 69.44086021505377
# Population_Group 69.48387096774194
# Finding 70.64516129032258
# Temporal_Concept 70.75268817204301
# Spatial_Concept 71.78494623655915
# Quantitative_Concept 72.10752688172043
# Cell_Function 72.10752688172043
# Manufactured_Object 72.10752688172043
# Professional_or_Occupational_Group 72.34408602150538
# Health_Care_Activity 72.34408602150538
# Genetic_Function 72.6236559139785
# Laboratory_Procedure 72.6236559139785
# Social_Behavior 72.88172043010752
# Occupation_or_Discipline 73.01075268817205
# Substance 73.11827956989248
# Pharmacologic_Substance 73.11827956989248
# Activity 73.11827956989248
# Organic_Chemical 73.11827956989248
# Clinical_Attribute 73.11827956989248
# Body_Substance 73.16129032258064
# Pathologic_Function 73.18279569892474
# Organism_Function 73.18279569892474
# Occupational_Activity 73.18279569892474
# Governmental_or_Regulatory_Activity 73.18279569892474
# Organization 73.20430107526882
# Immunologic_Factor 73.20430107526882
# Eukaryote 73.22580645161291
# Amino_Acid_Peptide_or_Protein 73.22580645161291
# Inorganic_Chemical 73.22580645161291
# Organ_or_Tissue_Function 73.22580645161291
# Vitamin 73.22580645161291
# Animal 73.22580645161291
# Chemical_Viewed_Structurally 73.22580645161291
# Natural_Phenomenon_or_Process 73.22580645161291
# Anatomical_Abnormality 73.22580645161291
# Physiologic_Function 73.22580645161291
# Indicator_Reagent_or_Diagnostic_Aid 73.22580645161291
# Carbohydrate_Sequence 73.22580645161291
# Physical_Object 73.22580645161291
# Amino_Acid_Sequence 73.22580645161291
# Human 73.22580645161291
# Chemical 73.22580645161291
# Biologic_Function 73.22580645161291
# Mental_or_Behavioral_Dysfunction 73.22580645161291
# Bird 73.22580645161291
# Fish 73.22580645161291
# Antibiotic 73.22580645161291
# Neoplastic_Process 73.22580645161291
# Cell_or_Molecular_Dysfunction 73.22580645161291
# Phenomenon_or_Process 73.22580645161291
# Acquired_Abnormality 73.22580645161291
# Research_Device 73.22580645161291
# Vertebrate 73.22580645161291
# Molecular_Biology_Research_Technique 73.22580645161291
# Gene_or_Genome 73.22580645161291
# Hormone 73.22580645161291
# Biomedical_Occupation_or_Discipline 73.22580645161291
# Daily_or_Recreational_Activity 73.22580645161291
# Environmental_Effect_of_Humans 73.22580645161291
# Event 73.22580645161291
# Experimental_Model_of_Disease 73.22580645161291
# Behavior 73.22580645161291
# Sign_or_Symptom 73.22580645161291
# Cell 73.22580645161291
# Entity 73.22580645161291
# Enzyme 73.22580645161291
# Language 73.22580645161291
# Group_Attribute 73.22580645161291
# Health_Care_Related_Organization 73.22580645161291
# Fully_Formed_Anatomical_Structure 73.22580645161291
# Human-caused_Phenomenon_or_Process 73.22580645161291
# Educational_Activity 73.22580645161291
# Congenital_Abnormality 73.22580645161291
# Mental_Process 73.22580645161291
# Tissue 73.22580645161291
# Hazardous_or_Poisonous_Substance 73.22580645161291
# Age_Group 73.22580645161291
# Nucleotide_Sequence 73.22580645161291
# Clinical_Drug 73.22580645161291
# Food 73.22580645161291
# Laboratory_or_Test_Result 73.22580645161291
# Injury_or_Poisoning 73.22580645161291
# Element_Ion_or_Isotope 73.22580645161291
# Medical_Device 73.22580645161291
# Organism_Attribute 73.22580645161291
# Nucleic_Acid_Nucleoside_or_Nucleotide 73.22580645161291
# Mammal 73.22580645161291
# Chemical_Viewed_Functionally 73.22580645161291
# Archaeon 73.22580645161291
# Body_Location_or_Region 73.22580645161291
# Organism 73.22580645161291
# Machine_Activity 73.22580645161291
# Professional_Society 73.22580645161291
# Body_Space_or_Junction 73.22580645161291
# Virus 73.22580645161291
# Self-help_or_Relief_Organization 73.22580645161291
# Plant 73.22580645161291
# Biologically_Active_Substance 73.22580645161291
# Body_Part_Organ_or_Organ_Component 73.22580645161291
# Body_System 73.22580645161291
# Anatomical_Structure 73.22580645161291
# Individual_Behavior 73.22580645161291
# Molecular_Function 73.22580645161291
# Bacterium 73.22580645161291
# Drug_Delivery_Device 73.22580645161291
# Geographic_Area 73.22580645161291
# Family_Group 73.22580645161291
# Reptile 73.22580645161291
# Fungus 73.22580645161291
# Embryonic_Structure 73.22580645161291
# Receptor 73.22580645161291
# Cell_Component 73.22580645161291
# Diagnostic_Procedure 73.22580645161291
# Amphibian 73.22580645161291
# Molecular_Sequence 73.22580645161291

# %%
writeMetrics('p', pd.DataFrame(merged_score_p_r.items()), 'metrics_gain_r')
writeMetrics('p', pd.DataFrame(merged_score_p_f1.items()), 'metrics_gain_f1')

writeMetrics('i', pd.DataFrame(merged_score_i_r.items()), 'metrics_gain_r')
writeMetrics('i', pd.DataFrame(merged_score_i_f1.items()), 'metrics_gain_f1')

writeMetrics('o', pd.DataFrame(merged_score_o_r.items()), 'metrics_gain_r')
writeMetrics('o', pd.DataFrame(merged_score_o_f1.items()), 'metrics_gain_f1')

# %%
writeMetrics('s', pd.DataFrame(merged_score_s_r.items()), 'metrics_gain_r')
writeMetrics('s', pd.DataFrame(merged_score_s_f1.items()), 'metrics_gain_f1')
