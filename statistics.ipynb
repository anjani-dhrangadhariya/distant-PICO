# %% [markdown]
# ## Source statistics

# %%
from elasticsearch import Elasticsearch, helpers
from elasticsearch_dsl import Search,  Q
from datetime import datetime
import sys, json, os
import difflib 
import uuid
import spacy
import ast
from statistics import mean, median
from collections import Counter

# %%
prim_outcomes = '/mnt/nas2/data/systematicReview/clinical_trials_gov/distant_pico_pre/primary_outcomes.txt'
counter = 0

outcome_names = []
outcome_tokens = []
pos_all = []
posfine_all = []
outcome_tokens_all = []

with open(prim_outcomes, 'r') as pof:
    try:
        
        for eachOutcome in pof:
            counter = counter + 1
            #rint(counter)
            j = json.loads(eachOutcome)

            if j:
                for key, value in j.items():
                    for eachOne in value:
                        if 'text' in eachOne:
                            outcome_names.append( eachOne['text'] )
                        if 'tokens' in eachOne:
                            outcome_tokens.append( eachOne['tokens'] )
                            outcome_tokens_all.extend( eachOne['tokens'] )
                        if 'pos' in eachOne:
                            pos_all.extend( eachOne['pos'] )
                        if 'pos_fine' in eachOne:
                            posfine_all.extend( eachOne['pos_fine'] )
                            

            #f counter == 10:
            #  break
    except:
        print('something strange happened')

print( len(outcome_names) )
print( len(outcome_tokens) )


longest_outcome = max(map(len, outcome_tokens))
print('Longest outcome term: ', longest_outcome)

shortest_outcome = min(map(len, outcome_tokens))
print('Longest outcome term: ', shortest_outcome)

mean_outcome = mean(map(len, outcome_tokens))
print('Mean outcome term: ', mean_outcome)

median_outcome = median(map(len, outcome_tokens))
print('Median outcome term: ', median_outcome)

pos_counter = Counter(pos_all)
print( pos_counter.most_common(50) )

posfine_counter = Counter(posfine_all)
print( posfine_counter.most_common(50) )

print('####################################################################')
# Most common words
print('Total number of unique tokens: ', len(outcome_tokens_all))
outcometerms_counter = Counter(outcome_tokens_all)
most_common_outcome_terms = outcometerms_counter.most_common(100)

for tuple_i in most_common_outcome_terms:
    print(tuple_i[0], '\t', tuple_i[1])
# Out:
# something strange happened
# 22985
# 22985
# Longest outcome term:  59
# Longest outcome term:  1
# Mean outcome term:  10.190211007178595
# Median outcome term:  8
# [('NOUN', 79871), ('PROPN', 36275), ('ADP', 35706), ('PUNCT', 25309), ('ADJ', 19418), ('VERB', 10459), ('DET', 8437), ('NUM', 7468), ('CCONJ', 5981), ('PART', 2665), ('ADV', 1081), ('PRON', 530), ('X', 333), ('AUX', 259), ('SCONJ', 253), ('SYM', 163), ('INTJ', 14)]
# [('NN', 67372), ('IN', 35880), ('NNP', 33437), ('JJ', 19008), ('NNS', 12500), ('-RRB-', 8675), ('-LRB-', 8364), ('DT', 8196), ('CD', 7468), ('CC', 5981), ('VBN', 4293), (',', 3328), ('NNPS', 2838), ('TO', 2345), ('VBG', 2335), ('.', 2188), ('VB', 1971), (':', 1702), ('RB', 1016), ('HYPH', 860), ('VBD', 727), ('VBP', 702), ('VBZ', 431), ('WP', 388), ('POS', 260), ('MD', 259), ('JJR', 247), ('FW', 231), ('WDT', 229), ('JJS', 163), ('SYM', 159), ('``', 118), ('WRB', 101), ('PRP$', 86), ('RP', 79), ("''", 67), ('XX', 65), ('PRP', 45), ('LS', 35), ('RBR', 20), ('UH', 14), ('EX', 10), ('NFP', 7), ('WP$', 6), ('PDT', 6), ('$', 4), ('RBS', 4), ('ADD', 2)]
# ####################################################################
# Total number of unique tokens:  234222
# of 	 12527
# ) 	 8329
# ( 	 8129
# in 	 6397
# the 	 5357
# and 	 4380
# , 	 3325
# to 	 3013
# Change 	 2906
# . 	 2166
# at 	 2151
# by 	 1734
# with 	 1723
# : 	 1480
# Number 	 1453
# from 	 1369
# for 	 1193
# as 	 1130
# - 	 1045
# Baseline 	 1019
# a 	 985
# From 	 984
# Participants 	 966
# or 	 941
# on 	 929
# With 	 903
# The 	 884
# rate 	 835
# baseline 	 830
# Scale 	 817
# Adverse 	 745
# after 	 737
# patients 	 723
# Time 	 699
# events 	 646
# 1 	 639
# 2 	 615
# Response 	 615
# adverse 	 609
# Percentage 	 603
# Incidence 	 583
# Events 	 574
# time 	 558
# change 	 545
# dose 	 539
# treatment 	 526
# 3 	 522
# measured 	 513
# response 	 510
# Week 	 505
# Safety 	 497
# Rate 	 489
# score 	 471
# Score 	 471
# concentration 	 459
# Dose 	 442
# plasma 	 441
# Phase 	 439
# participants 	 438
# 12 	 437
# 6 	 436
# blood 	 426
# assessed 	 426
# Mean 	 420
# Cmax 	 419
# Maximum 	 414
# Area 	 411
# Pain 	 411
# Changes 	 407
# Plasma 	 405
# months 	 394
# week 	 390
# To 	 374
# Treatment 	 373
# pain 	 369
# safety 	 364
# Assessment 	 363
# 4 	 361
# survival 	 360
# Concentration 	 356
# Part 	 354
# using 	 352
# 24 	 346
# % 	 343
# during 	 340
# subjects 	 333
# study 	 332
# Total 	 319
# weeks 	 313
# 0 	 306
# severe 	 306
# AUC 	 292
# Overall 	 291
# Clinical 	 289
# between 	 285
# Rating 	 281
# tolerability 	 279
# level 	 268
# ] 	 263
# under 	 259
